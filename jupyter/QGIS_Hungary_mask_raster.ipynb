# %% [markdown]
# ## The Program

# %% [markdown]
# # The function library

# %%
import sys
sys.path.append('/opt/homebrew/lib/python3.10/site-packages')
sys.path.append('/opt/homebrew/lib/python3.11/site-packages')
sys.path.append('/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages')
import numpy as np
import pandas as pd
from osgeo import gdal
import shapely
from shapely.geometry import Point, LineString
import geopandas as gpd
import basemap
import math
import requests
import json
import fiona
from openpyxl import load_workbook
import random
from statistics import mean

#import xarray as xr
# import rioxarray # https://corteva.github.io/rioxarray/html/installation.html
import rasterio

#import rasterio.plot
#import rasterio.mask
#import rasterio.features
import rasterstats

#import cfgrib

#%matplotlib inline

# %%
pd.set_option('display.max_columns', 250)
pd.set_option('display.max_rows', 2000)

# %%
layer_name = fiona.listlayers('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/city saved/OSM_Cities_Hun_Points.gpkg')
OSM_Cities_Hun = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/city saved/OSM_Cities_Hun_Points.gpkg',layer = layer_name[0])

# %%
#####

# read in Files of mine locations
hist_mines = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/Mining/historical_mines.dat')
contemp_mines = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/Mining/contemp_mines.dat')
miningfeature = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/Mining/m4eu20211209.gpkg',layer = 'miningfeatureoccurrence')
miningfeature.to_crs(epsg=3857, inplace=True)
hist_mines.to_crs(epsg=3857, inplace=True)
contemp_mines.to_crs(epsg=3857, inplace=True)
####

def calc_previous_population(campaigntime):
    """
    for settlements get the wikidata entity, download the json and extract the inception property P571
    also get population from wikidata.
    Calculate the population at campaign-time
    Delete Settlements without a wikidata item id
    Delete Settlements with inception time after Campaign time
    """
    # caps = settlement_layer.dataProvider().capabilities(
    layer_name = fiona.listlayers('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/city saved/OSM_Cities_Hun_Points.gpkg')
    OSM_Cities_Hun = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/city saved/OSM_Cities_Hun_Points.gpkg',layer = layer_name[0])
    
    OSM_Cities_Hun.set_index('osm_id', drop=False, inplace=True) #drop=False means that the COORDIDX collumn is not deleted
    OSM_Cities_Hun.index.names = ['IDX']
    
    # campaigntime = 1200
    pop_at_campaigntime_string = 'POP'+str(campaigntime)

    OSM_Cities_Hun['inception'] = 0.0 * OSM_Cities_Hun.shape[0]
    OSM_Cities_Hun[pop_at_campaigntime_string] = '' * OSM_Cities_Hun.shape[0]


    filt = OSM_Cities_Hun['wikidata'].notna() # only keep rows with a wikidata entry
    filtOSM=OSM_Cities_Hun.loc[filt] # apply filter
    features_to_delete = []
    for indx in filtOSM.index:
            # srcindx = feat.fieldNameIndex('wikidata') # srcindx sourceindex. Source of data, in this case the item Q
            fid = indx # to append to features_to_delete
            # print('Feature ID: ', feat.id())
            q = filtOSM.loc[indx,'wikidata'] # get the attribute, in this case the Q... srcindx is 146
            #print('Wikidata Item: ' , q)
            requeststring = 'https://m.wikidata.org/wiki/Special:EntityData/'+ str(q) + '.json' 
            x = requests.get(requeststring)
            y = json.loads(x.content) #convert json to python object
            try: # will fail if P571 == inception does not exist
                inception = y['entities'][q]['claims']['P571'][0]['mainsnak']['datavalue']['value']['time']
                IntInception = int(inception[:5])
                output = inception
                #print(output)
                #print(IntInception)
            except: # if fall through, append feature id to list of to-be-deleted features == rows
                IntInception = np.nan
                output = 'no_inception'
                features_to_delete.append(fid)
            #print('output: ', output)
            OSM_Cities_Hun.loc[indx, 'inception'] = IntInception
            if output != 'no_inception':
                if int(IntInception) > campaigntime: # this is crude. Year is first five of isostring. cast to int.
                        features_to_delete.append(fid) # leave only 1200 and earlier
            
            #print ('destindx: ', destindx)
            

            try: # if there is a wikidata entry for population, insert this into the dataframe
                temp_population = y['entities'][q]['claims']['P1082'][0]['mainsnak']['datavalue']['value']['amount'] #P1082
            except: 
                #print ('population not updated')
                temp_population = ''
            if not temp_population == '' and not math.isnan(IntInception):
                OSM_Cities_Hun.loc[indx,'population'] = temp_population
                # round(((1200 - to_int('Inception'))/4500)*to_int('population'))
                # formula from alexis. https://wiki.alexissmolensk.com/index.php/Settlements Heading 'Determining Settlement Population'
                OSM_Cities_Hun.loc[indx, pop_at_campaigntime_string] = round(((int(campaigntime) - round(OSM_Cities_Hun.loc[indx,'inception']))/4500)*int(OSM_Cities_Hun.loc[indx,'population']))
            else:
                 pass
                #print('calculation of campaign-time population failed')
            #print('End of loop---------')
    #print('Deletion part---------')
    #print (features_to_delete)
    # res = settlement_layer.dataProvider().deleteFeatures(features_to_delete) # delete all featuers without an inception
    
    # for i in features_to_delete:
    #         dropFilt = OSM_Cities_Hun['osm_id'] == i
    #         OSM_Cities_Hun.drop(dropFilt)
    #         # settlement_layer.deleteFeature(i) # https://gis.stackexchange.com/questions/316057/deleting-features-in-pyqgis
    # pass
    #         # don't update the feature https://gis.stackexchange.com/questions/316057/deleting-features-in-pyqgis
    return OSM_Cities_Hun

######
pd.set_option('display.max_columns', 250)
######
pd.set_option('display.max_rows', 2000)
#######
hexgrid30km = gpd.read_file("/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/30KMHungaryClip.shp")
##########
hexgrid30km['COORDIDX'] = [''] * hexgrid30km.shape[0]
for index3, feature3 in  hexgrid30km.iterrows():
    hexgrid30km.loc[index3,'COORDIDX'] = str(feature3['COORDX']) + '.' + str(feature3['COORDY'])
######
hexgrid30km.set_index('COORDIDX', drop=False, inplace=True) #drop=False means that the COORDIDX collumn is not deleted
hexgrid30km.index.names = ['IDX']
#######
hexgrid30km['COORDIDX'] = hexgrid30km['COORDIDX'].apply(lambda x: str(x)) # just to make sure that index is str
######
settls = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/CityHungaryEPSG3857.shp')
########
hexgrid10km = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10kmHungary Copy.shp')
######
hexgrid10km.set_index('COORDIDX', drop=False, inplace=True) #drop=False means that the COORDIDX collumn is not deleted
hexgrid10km.index.names = ['IDX']
######
# open Alexis' Table of Hex-Types per Infrastructure
with open("/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/JSON/hex_generator_table.json", "r") as openfile:
    allInfras = json.load(openfile)
######
area = 301
#######
def add_settlement_to_hex(hexgrid30km,settls):
    hexgrid30km['OriginalInfra'] = [0] * hexgrid30km.shape[0]
    area = 301
    Match_Settlements_Ids = []
    for index1, feature1 in  hexgrid30km.iterrows():
        Match_Settlements_Ids = []
        pop_in_cell = []
        for index2, feature2 in  settls.iterrows():
            if feature1['geometry'].contains(feature2['geometry']):
                MatchGridCOORDIDX = feature1['COORDIDX']
                Match_Settlements_Ids.append(str(index2))
                pop_in_cell.append(int(feature2['POP1200']))
                # print('match' )
        if Match_Settlements_Ids: #truth value testing of python list. 
            list_of_strings = []
            for number in Match_Settlements_Ids:
                list_of_strings.append(str(number))
                #print(round(sum(pop_in_cell)/300))
                # once to JSON ...
                #hexgrid30kmJSON.settl[MatchGridCOORDIDX] = ' '.join(list_of_strings) 
                #hexgrid30kmJSON.infra[MatchGridCOORDIDX] = round((sum(pop_in_cell))/area)
                # ... and one to dataframe
                filt = hexgrid30km['COORDIDX'] == MatchGridCOORDIDX
                hexgrid30km.loc[filt,'settl'] = ' '.join(list_of_strings) # with COORDIDX as index, filtering is no longer necessary
                #print('infra before update',hexgrid30km.loc[filt,'Infra'])
                # hexgrid30km.loc[filt,'Infra'] = round((sum(pop_in_cell))/area) commented out because otherwise double
                hexgrid30km.loc[filt,'OriginalInfra'] = round((sum(pop_in_cell))/area)
                #print('infra after update',hexgrid30km.loc[filt,'Infra'])
    return hexgrid30km
                
#######
def ring_around(center, hexgrid30km ,radius):
    """
    Takes a hex object, the corrdinates of the center and the radius and 
    returns a set with the coordinates of the hexes in the ring around 
    the center
    """
    if radius < 0:
        return set()
    if radius == 0:
        return set([center])

    # stuff to get hex ring. Read up on numpy to simplify
    SE = np.array((1, 0, -1))
    SW = np.array((0, 1, -1))
    W = np.array((-1, 1, 0))
    NW = np.array((-1, 0, 1))
    NE = np.array((0, -1, 1))
    E = np.array((1, -1, 0))
    ALL_DIRECTIONS = np.array([NW, NE, E, SE, SW, W, ])
    offset_ring = []



    # print('center: ', center)
    #print('hexgrid30km.x[center]', hexgrid30km.x[center])

    col = int(center.split('.')[0])
    row = int(center.split('.')[1])

    #col = hexgrid30km.x[center]
    #row = hexgrid30km.y[center]
    q = col
    r = row - (col + col%2) / 2
    # coordsqr = np.array([q,r])   # convert to pseudo-multidimensional array for get_ring
    cube_x = q
    cube_z = r
    cube_y = -q - r
    cube_coords = np.vstack((cube_x, cube_y, cube_z)).T

    rad_hex = np.zeros((6 * radius, 3))
    #print('rad_hex after initialization: \n', rad_hex)
    count = 0
    for i in range(0, 6):
        for k in range(0, radius):
            rad_hex[count] = ALL_DIRECTIONS[i - 1] * (radius - k) + ALL_DIRECTIONS[i] * (k)
            #print ('dir:',i ,'rad_hex:\n ', rad_hex)
            count += 1
    #print('rad_hex all directions:\n', rad_hex)

    cube_ring =  np.squeeze(rad_hex) + cube_coords
    ax_ring = np.vstack((cube_ring[:, 0], cube_ring[:, 2])).T

    for i in range(len(ax_ring)):
        hex_tile = ax_ring[i]
        col = hex_tile[0]
        row = hex_tile[1] + (hex_tile[0] + (hex_tile[0]%2)) / 2
        intx = int(col)
        inty = int(row)
        strx = str(intx)
        stry = str(inty)
        strCoords = strx + '.' + stry
        offset_ring.append(strCoords)
    ring_on_map = set()
    for i in offset_ring:
        if i in hexgrid30km['COORDIDX']:
            ring_on_map.add(i)
        else:
            pass
               #print('COORDS not on grid_layer')
    # print('end of ring_around')
    return ring_on_map
########
def hex_group(center,radius):
    """
    Takes a hex object, the corrdinates of the center and the radius and 
    returns a set with the coordinates of the hexes in the ring around 
    the center
    """
    if radius < 0:
        return set()
    if radius == 0:
        return set([center])

    # stuff to get hex ring. Read up on numpy to simplify
    SE = np.array((1, 0, -1))
    SW = np.array((0, 1, -1))
    W = np.array((-1, 1, 0))
    NW = np.array((-1, 0, 1))
    NE = np.array((0, -1, 1))
    E = np.array((1, -1, 0))
    ALL_DIRECTIONS = np.array([NW, NE, E, SE, SW, W, ])
    offset_ring = []



    # print('center: ', center)
    col = int(center.split('.')[0])
    row = int(center.split('.')[1])
    q = col
    r = row - (col + col%2) / 2
    # coordsqr = np.array([q,r])   # convert to pseudo-multidimensional array for get_ring
    cube_x = q
    cube_z = r
    cube_y = -q - r
    cube_coords = np.vstack((cube_x, cube_y, cube_z)).T

    rad_hex = np.zeros((6 * radius, 3))
    #print('rad_hex after initialization: \n', rad_hex)
    count = 0
    for i in range(0, 6):
        for k in range(0, radius):
            rad_hex[count] = ALL_DIRECTIONS[i - 1] * (radius - k) + ALL_DIRECTIONS[i] * (k)
            #print ('dir:',i ,'rad_hex:\n ', rad_hex)
            count += 1
    #print('rad_hex all directions:\n', rad_hex)

    cube_ring =  np.squeeze(rad_hex) + cube_coords
    ax_ring = np.vstack((cube_ring[:, 0], cube_ring[:, 2])).T

    for i in range(len(ax_ring)):
        hex_tile = ax_ring[i]
        col = hex_tile[0]
        row = hex_tile[1] + (hex_tile[0] + (hex_tile[0]%2)) / 2
        intx = int(col)
        inty = int(row)
        strx = str(intx)
        stry = str(inty)
        strCoords = strx + '.' + stry
        offset_ring.append(strCoords)
    group = set()
    for i in offset_ring:
        group.add(i)

    #return group
    return offset_ring

#######
def edge_hexes(center):
    """
    i dont know what i'm doing but it seems to work
   
    """
    
    offset_ring = []

    top_left = np.array((-1, -1, 2))
    left =  np.array((- 2, 1, 1))
    bottom_left = np.array((-1, 2, -1))
    bottom_right = np.array((1, 1, -2))
    right = np.array((2, -1 ,-1))
    top_right = np.array((1, -2, 1))
    EDGE_HEXES = np.array([top_left, left, bottom_left, bottom_right, right, top_right])


    col = int(center.split('.')[0])
    row = int(center.split('.')[1])
    q = col
    r = row - (col + col%2) / 2
    # coordsqr = np.array([q,r])   # convert to pseudo-multidimensional array for get_ring
    cube_x = q
    cube_z = r
    cube_y = -q - r
    cube_coords = np.vstack((cube_x, cube_y, cube_z)).T

    cube_ring = EDGE_HEXES + cube_coords

    ax_ring = np.vstack((cube_ring[:, 0], cube_ring[:, 2])).T

    for i in range(len(ax_ring)):
        hex_tile = ax_ring[i]
        col = hex_tile[0]
        row = hex_tile[1] + (hex_tile[0] + (hex_tile[0]%2)) / 2
        intx = int(col)
        inty = int(row)
        strx = str(intx)
        stry = str(inty)
        strCoords = strx + '.' + stry
        offset_ring.append(strCoords)
    edges = set()
    for i in offset_ring:
        edges.add(i)

    # return edges
    return offset_ring
#########
def propagate(hex1_COORDS,hexgrid30km):
    

    radius = 0
    while radius < 40: # and round(hexgrid30km.loc[hexgrid30km['COORDIDX'] == str(hex1_COORDS), 'Infra'].item() * (1/2)** radius): # 40 is widest
    # while hex(radius) < max(height, length) and round(infra(COORD1) * (1/2)**i )> 0 

    # last_ring = ring_around(hex1coord, hexgrid30km, radius-1)
        this_ring = ring_around(hex1_COORDS, hexgrid30km, radius)#.union(hexes_on_rid)
        # print('this_ring: ', this_ring)
        next_ring = ring_around(hex1_COORDS, hexgrid30km, radius+1)#.union(hexes_on_rid)
        # print('next_ring: ',next_ring)
        for hex in this_ring:
            three_adjacent_hexes = set.union(ring_around(hex,hexgrid30km,1),next_ring)
            for adjacent_hex in three_adjacent_hexes:
                if float(hexgrid30km.loc[hex,'MeanElev']) >  float(hexgrid30km.loc[adjacent_hex,'MeanElev']):
                    diff = float(hexgrid30km.loc[hex,'MeanElev']) - float(hexgrid30km.loc[adjacent_hex,'MeanElev'])
                else:
                    diff = float(hexgrid30km.loc[adjacent_hex,'MeanElev']) - float(hexgrid30km.loc[hex,'MeanElev'])

                exponent = math.ceil(diff/150) # meters. If < 150 m result in 1, so that 1/2**1 = 1/2
                calculated_Infra = round(hexgrid30km.loc[hex,'update'] /(2**exponent))  #hexgrid30km.loc[hex,'update']
                # print('calculated_Infra',calculated_Infra)
                # print(' = round(hex.infra[hex1_COORDS]',hexgrid30km.loc[hex,'update'])
                # print(' /(2**exponent))',exponent)
                # print('hexgrid30km.loc[adjacent_hex,"update"] before update',hexgrid30km.loc[adjacent_hex,'update'],'type: ',type(hexgrid30km.loc[adjacent_hex,'update']))
                if hexgrid30km.loc[adjacent_hex,'update'] == 0 or hexgrid30km.loc[adjacent_hex,'update'] <= calculated_Infra:
                    hexgrid30km.loc[adjacent_hex,'update'] = calculated_Infra
                    # print('hexgrid30km.loc[adjacent_hex,"update"] after update',hexgrid30km.loc[adjacent_hex,'update'])
                else:
                    # print('no update of',adjacent_hex)
                    pass

        radius +=1 
    ## es fehlt hexgrid30km infra += hexgrid30km update
    for key6 in hexgrid30km.index:
         # print('key6', key6)
         hexgrid30km.loc[key6,'Infra'] += hexgrid30km.loc[key6,'update'] 
         # print('hexgrid30km.infra[key6]',hexgrid30km.infra[key6],' hexgrid30kmJSON.update[key6]',hexgrid30kmJSON.update[key6])

    return hexgrid30km 

####
hexgrid30km['Hex_Group'] = '' * hexgrid30km.shape[0]
#hexgrid30km['Hex_Group'] = hexgrid30km['Hex_Group'].apply(lambda x: {})
hexgrid30km['Edge_Hexes'] = '' * hexgrid30km.shape[0]
#hexgrid30km['Edge_Hexes'] = hexgrid30km['Hex_Group'].apply(lambda x: [])
#####
def small_hexes_in_big_hexes(hexgrid30km):
    # make a temporary centroid dict for hex groups and edge hexes later
    centroid = {}
    for key7 in hexgrid30km.index:
        centroid[key7] = ''
        
    y30 = 0 + 392
    x30 = 0 + 724
    x10 = 1
    y10 = 2
    while y30 < (28 + 392): # max 419
        while x30 < (39 + 724): # max 762
            #print(str(x30)+'.'+ str(y30))
            #print(hexgrid30km.centroid[str(x30)+'.'+ str(y30)])
            # hexgrid30km[str(x30)+'.'+ str(y30), 'centroid'] = str(x10)+'.'+ str(y10)
            centroid[str(x30)+'.'+ str(y30)] = str(x10)+'.'+ str(y10)# temp var centroid better than col
            #print('hexgrid30km.centroid[',str(x30)+'.'+ str(y30),']', hexgrid30km.centroid[str(x30)+'.'+ str(y30)])
            #hexgrid30km.Hex_Group[str(x30)+'.'+ str(y30)].append(ring_around(hexgrid30km.centroid[str(x30)+'.'+ str(y30)],hexgrid30km,1))
            #hexgrid30km.Hex_Group = ring_around(hexgrid30km.centroid[str(x30)+'.'+ str(y30)],hexgrid30km,1)
            x30 += 2
            x10 += 6
        
        y30 += 1
        y10 += 3
        #reset x
        x30 = 0 + 724
        x10 = 1

        # print('new y loop even y: ', y30)

    # reset: 
    y30 = 0 + 392
    x30 = 1 + 724
    x10 = 4
    y10 = 0

    while y30 < (28 +  392):
        while x30 < (39 + 724):
            #print(hexgrid30km.centroid[str(x30)+'.'+ str(y30)])
            # hexgrid30km[str(x30)+'.'+ str(y30),'centroid'] = str(x10)+'.'+ str(y10)
            centroid[str(x30)+'.'+ str(y30)] = str(x10)+'.'+ str(y10) # temp var centroid better than col
            #hexgrid30km.Hex_Group[str(x30)+'.'+ str(y30)].append(ring_around(hexgrid30km.centroid[str(x30)+'.'+ str(y30)],hexgrid30km,1))
            x30 += 2
            x10 += 6

        y30 += 1
        y10 += 3

        #reset x
        x30 = 1 + 724
        x10 = 4
        #print('new y loop odd y: ', y30)


    # delete empty lists
    temp = {k: v for k, v in centroid.items() if v} # dictionary comprehension with conditional. https://www.programiz.com/python-programming/dictionary-comprehension
    centroid = temp
    # breakpoint()
    # find hex groups for centoids
    #for key10, value10 in hexgrid30km['centroid'].items():
    for key10, value10 in centroid.items():
        if key10 in hexgrid30km.index:
        # breakpoint()
        # temp = hex_group(value10,1)
        # list_of_strings = [str(x) for x in temp]
        
            list = hex_group(value10,1) # list of ring around centroid.
            list.append(value10) # append the centroid to the hex group
            dict = {'HexA' : list[0], 'HexB': list[1], 'HexC':list[2],'HexD':list[3],'HexE':list[4],'HexF':list[5], 'HexG':list[6]}
            dictJSON = json.dumps(dict)
            hexgrid30km.at[key10, 'Hex_Group'] = dictJSON
    
    ## delete empty list
    # temp1 = {k: v for k, v in hexgrid30km.Hex_Group.items() if v}
    # hexgrid30km.Hex_Group = temp1

    # append centroid to hex group
    #for key11, value11 in hexgrid30km['centroid'].items():
    # for key11, value11 in centroid.items():
    #     if key11 in hexgrid30km.index:
    #         hexgrid30km[key11,'Hex_Group'].append(value11)

    # find edge hexes
    for key12, value12 in centroid.items():
        egdelist = edge_hexes(value12)
        egdeJSON = json.dumps(egdelist)
        hexgrid30km.at[key12, 'Edge_Hexes'] = egdeJSON

    # later access with
    """
    filt = hexgrid30km['Edge_Hexes'].astype(bool)# check if list is empty
    """
    # list comprehension returns a list and not a boolen mask
    # [x for x in hexgrid30km['Edge_Hexes'] if x]
    """
    for i in hexgrid30km.loc[filt,'Edge_Hexes']:
    """

    
    ## delete empty lists
    # temp2 = {k: v for k, v in hexgrid30km.Edge_Hexes.items() if v}
    # hexgrid30km.Edge_Hexes = temp2


    # for key13 in hexgrid30km['Hex_Group'].keys():
        
    #     hexgrid30km.at[key13,'Hex_Group'] = {'HexA' : hexgrid30km.Hex_Group[key13][0], 'HexB': hexgrid30km.Hex_Group[key13][1], 'HexC':hexgrid30km.Hex_Group[key13][2],'HexD':hexgrid30km.Hex_Group[key13][3],'HexE':hexgrid30km.Hex_Group[key13][4],'HexF':hexgrid30km.Hex_Group[key13][5], 'HexG':hexgrid30km.Hex_Group[key13][6]}
              
     


    return hexgrid30km

hexgrid30km['Hex_Type'] = '' * hexgrid30km.shape[0]
hexgrid10km['HexType'] = 0 * hexgrid10km.shape[0]


#####
def getHexGroup(allInfras,infra):
    """
    generates a dict of hex-Types for a 10km hex hex group. Input is Alexis' Table of Hex-Types per Infrastructure and the 30 km Infrastructure
    """


    while allInfras[infra] ==[]: # if there is no entry for the infra-value, reduce the infra valute until a non-empty row is met. So it "rounds down"
        infra = str(int(infra)-1)
    randIdx = random.randint(0,len(allInfras[infra])-1)
    randHexTypeDistro = allInfras[infra][randIdx]

    HexGroup = [0,0,0,0,0,0,0]
    HexGroupDict = {'HexA' : 0, 'HexB': 0, 'HexC':0,'HexD':0,'HexE':0,'HexF':0, 'HexG':0}


    HexTypeIdx = 0
    HexGroupIdx = 0
    while HexTypeIdx <= 7:
        count = 0
        while count < randHexTypeDistro[HexTypeIdx]: 
            HexGroup[HexGroupIdx] = HexTypeIdx +1
            count +=1
            HexGroupIdx +=1 # next Hex
        HexTypeIdx += 1
    
    randHexGropup = random.sample(HexGroup, 7)
    HexGroupDict = {'HexA' : randHexGropup[0], 'HexB': randHexGropup[1], 'HexC':randHexGropup[2],'HexD':randHexGropup[3],'HexE':randHexGropup[4],'HexF':randHexGropup[5], 'HexG':randHexGropup[6]}
    
    return json.dumps(HexGroupDict)



### 
hexgrid30km['Infra'] = [0] * hexgrid30km.shape[0]
hexgrid30km['update'] = [0] * hexgrid30km.shape[0]
hexgrid30km = add_settlement_to_hex(hexgrid30km,settls) # initialize


###
# write hex types to hexgrid10km
def write_HexType_to_10km(hexgrid30km, hexgrid10km):
    for j in hexgrid30km.index:
        if hexgrid30km.loc[j,'Hex_Group'] !='':
            dict_of_groupJSON = hexgrid30km.loc[j,'Hex_Group']
            # print(dict_of_groupJSON)
            dict_of_group = json.loads(dict_of_groupJSON)

            dict_of_typeJSON = hexgrid30km.loc[j,'Hex_Type']
            dict_of_type = json.loads(dict_of_typeJSON)
            for key90, value90 in dict_of_group.items():
                for key91,value91 in dict_of_type.items():
                    if key90 == key91:
                        hexgrid10km.loc[value90,'HexType'] = value91
                    else:
                        #print('keys do not match for coord', value90)
                        pass
    return hexgrid10km


####

def edge_hex_type(hexgrid30km,hexgrid10km):

    # needs hex groups in 10 km hexes
    filt = hexgrid30km['Edge_Hexes'].str.len() !=0 # check if str is empty, 
    Edge_Hexes_on_grid = []

    for Edge_Hex_ListJSON in hexgrid30km.loc[filt,'Edge_Hexes']: 
        Edge_Hex_List = json.loads(Edge_Hex_ListJSON)
        for Edge_Hex in Edge_Hex_List:
            if Edge_Hex in hexgrid10km.index:
                Edge_Hexes_on_grid.append(Edge_Hex)

    Edge_Hexes_on_grid = list(set(Edge_Hexes_on_grid)) # removes duplicates

# has been updated, should work now
    COORDIDX_10km_Edge_Hex = {}
    ring_hex_types = []
    for this_Edge_Hex in Edge_Hexes_on_grid:
        ring_around_Edge = hex_group(this_Edge_Hex,1)
        for ring_hex in ring_around_Edge:
            if ring_hex in hexgrid10km['IDX'].to_list():
                # if ring_hex in COORDIDX_10km_HexGroup: # where in 10km grid or 30 km grid
                ring_hex_types.append(hexgrid10km.loc[hexgrid10km['IDX'] == ring_hex,'HexType'].to_list()[0]) # to_list() because it returns a series
                # else:
                    #print(ring_hex, 'not on Grid')
                    # pass
        if len(ring_hex_types) != 0:
            mean_type = round(mean(ring_hex_types))
        print("before: ", hexgrid10km.loc[hexgrid10km['IDX'] == this_Edge_Hex,'HexType'])    
        hexgrid10km.loc[hexgrid10km['IDX'] == this_Edge_Hex,'HexType'] = mean_type
        print("after:", hexgrid10km.loc[hexgrid10km['IDX'] == this_Edge_Hex,'HexType'])
        ring_hex_types = []

    return hexgrid10km
####

# first set_hammers

#############################
def set_bread(hexgrid10km):
    bread = {'rural' : {'0': -1,'1': 5, '2':4, '3':3 , '4':3, '5':3, '6':2, '7': 2, '8':1 },
            'settl' : {'0': -1,'1': 6, '2':5, '3': 4, '4':4, '5':4, '6':3, '7': 3, '8': 0}
             }

    hexgrid10km['Bread'] = 0 * hexgrid10km.shape[0] #initialize new column
    for i in hexgrid10km.index:
        hexgrid10km.loc[i,'Bread'] = 0
        # if any([pd.notna(hexgrid10km.loc[i,'main_commo']), pd.notna(hexgrid10km.loc[i,'commodity']),pd.notna(hexgrid10km.loc[i,'IDminingfe'])]):
        # hexgrid10km.loc[i,'Bread'] = -1
        # Hextype of corner hexes is 0!
        if pd.notna(hexgrid10km.loc[i,'IDsettl']):
            hexgrid10km.loc[i,'Bread'] = bread['settl'][hexgrid10km.loc[i,'HexType'].astype(int).astype(str)]
        else:
            hexgrid10km.loc[i,'Bread'] = bread['rural'][hexgrid10km.loc[i,'HexType'].astype(int).astype(str)]
    return hexgrid10km

###

# %% [markdown]
# Hextype of Corner Hexes is 0. Need to revise

# %%
hexgrid10km = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10kmHungary Copy with Bread.shp')

# %%
bread = {'rural' : {'0': -1,'1': 5, '2':4, '3':3 , '4':3, '5':3, '6':2, '7': 2, '8':1 },
            'settl' : {'0': -1,'1': 6, '2':5, '3': 4, '4':4, '5':4, '6':3, '7': 3, '8': 0}
            }

# %% [markdown]
# Addressing Cells: If you want to find a cell with a certain index, this is how you do it

# %%
#If you want to find a cell with a certain index, this is how you do it
df.loc[df['IDX']== '10.14','Bread']
# If you want to show multiple columns
df.loc[df['IDX']== '10.14',['Bread','HexType','IDsettl']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 #If you want to find a cell with a certain index, this is how you do it
# ----> 2 df.loc[df['IDX']== '10.14','Bread']
#       3 # If you want to show multiple columns
#       4 df.loc[df['IDX']== '10.14',['Bread','HexType','IDsettl']]
#
# NameError: name 'df' is not defined

# %%
# Read in, now truncated colum lables
def set_bread(hexgrid10km):
    bread = {'rural' : {'0': -1,'1': 5, '2':4, '3':3 , '4':3, '5':3, '6':2, '7': 2, '8':1 },
            'settl' : {'0': -1,'1': 6, '2':5, '3': 4, '4':4, '5':4, '6':3, '7': 3, '8': 0}
             }

    hexgrid10km['Bread'] = 0 * hexgrid10km.shape[0] #initialize new column
    for i in hexgrid10km.index:
        hexgrid10km.loc[i,'Bread'] = 0
        # if any([pd.notna(hexgrid10km.loc[i,'main_commo']), pd.notna(hexgrid10km.loc[i,'commodity']),pd.notna(hexgrid10km.loc[i,'IDminingfe'])]):
        # hexgrid10km.loc[i,'Bread'] = -1
        # Hextype of corner hexes is 0!
        if pd.notna(hexgrid10km.loc[i,'IDsettl']):
            hexgrid10km.loc[i,'Bread'] = bread['settl'][hexgrid10km.loc[i,'HexType'].astype(int).astype(str)]
        else:
            hexgrid10km.loc[i,'Bread'] = bread['rural'][hexgrid10km.loc[i,'HexType'].astype(int).astype(str)]
    return hexgrid10km

hexgrid10km = set_bread(hexgrid10km)

# %% [markdown]
# ## Find HexType for Edge Hexes

# %%
with open("/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/JSON/Edge_Hexes_on_grid.json", "r") as openfile:
    Edge_Hexes_on_grid = json.load(openfile)
    ring_hex_types = []
    for this_Edge_Hex in Edge_Hexes_on_grid:
        ring_around_Edge = hex_group(this_Edge_Hex,1)
        for ring_hex in ring_around_Edge:
            if ring_hex in hexgrid10km['IDX'].to_list():
                # if ring_hex in COORDIDX_10km_HexGroup: # where in 10km grid or 30 km grid
                ring_hex_types.append(hexgrid10km.loc[hexgrid10km['IDX'] == ring_hex,'HexType'].to_list()[0]) # to_list() because it returns a series
                # else:
                    #print(ring_hex, 'not on Grid')
                    # pass
        if len(ring_hex_types) != 0:
            mean_type = round(mean(ring_hex_types))
        print("before: ", hexgrid10km.loc[hexgrid10km['IDX'] == this_Edge_Hex,'HexType'])    
        hexgrid10km.loc[hexgrid10km['IDX'] == this_Edge_Hex,'HexType'] = mean_type
        print("after:", hexgrid10km.loc[hexgrid10km['IDX'] == this_Edge_Hex,'HexType'])
        ring_hex_types = []

    hexgrid10km.to_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10kmHungarybreadRevised.shp')
# Out:
# before:  172    0.0
# Name: HexType, dtype: float64
# after: 172    8.0
# Name: HexType, dtype: float64
# before:  3814    0.0
# Name: HexType, dtype: float64
# after: 3814    8.0
# Name: HexType, dtype: float64
# before:  1526    0.0
# Name: HexType, dtype: float64
# after: 1526    6.0
# Name: HexType, dtype: float64
# before:  6071    0.0
# Name: HexType, dtype: float64
# after: 6071    8.0
# Name: HexType, dtype: float64
# before:  6617    0.0
# Name: HexType, dtype: float64
# after: 6617    7.0
# Name: HexType, dtype: float64
# before:  9868    0.0
# Name: HexType, dtype: float64
# after: 9868    5.0
# Name: HexType, dtype: float64
# before:  5800    0.0
# Name: HexType, dtype: float64
# after: 5800    8.0
# Name: HexType, dtype: float64
# before:  9617    0.0
# Name: HexType, dtype: float64
# after: 9617    8.0
# Name: HexType, dtype: float64
# before:  4661    0.0
# Name: HexType, dtype: float64
# after: 4661    8.0
# Name: HexType, dtype: float64
# before:  3259    0.0
# Name: HexType, dtype: float64
# after: 3259    8.0
# Name: HexType, dtype: float64
# before:  3796    0.0
# Name: HexType, dtype: float64
# after: 3796    8.0
# Name: HexType, dtype: float64
# before:  5323    0.0
# Name: HexType, dtype: float64
# after: 5323    8.0
# Name: HexType, dtype: float64
# before:  2627    0.0
# Name: HexType, dtype: float64
# after: 2627    6.0
# Name: HexType, dtype: float64
# before:  6897    0.0
# Name: HexType, dtype: float64
# after: 6897    8.0
# Name: HexType, dtype: float64
# before:  2513    0.0
# Name: HexType, dtype: float64
# after: 2513    7.0
# Name: HexType, dtype: float64
# before:  9662    0.0
# Name: HexType, dtype: float64
# after: 9662    8.0
# Name: HexType, dtype: float64
# before:  2737    0.0
# Name: HexType, dtype: float64
# after: 2737    8.0
# Name: HexType, dtype: float64
# before:  2275    0.0
# Name: HexType, dtype: float64
# after: 2275    6.0
# Name: HexType, dtype: float64
# before:  6374    0.0
# Name: HexType, dtype: float64
# after: 6374    5.0
# Name: HexType, dtype: float64
# before:  7724    0.0
# Name: HexType, dtype: float64
# after: 7724    8.0
# Name: HexType, dtype: float64
# before:  9182    0.0
# Name: HexType, dtype: float64
# after: 9182    8.0
# Name: HexType, dtype: float64
# before:  1496    0.0
# Name: HexType, dtype: float64
# after: 1496    5.0
# Name: HexType, dtype: float64
# before:  7178    0.0
# Name: HexType, dtype: float64
# after: 7178    8.0
# Name: HexType, dtype: float64
# before:  9236    0.0
# Name: HexType, dtype: float64
# after: 9236    8.0
# Name: HexType, dtype: float64
# before:  3536    0.0
# Name: HexType, dtype: float64
# after: 3536    8.0
# Name: HexType, dtype: float64
# before:  3641    0.0
# Name: HexType, dtype: float64
# after: 3641    8.0
# Name: HexType, dtype: float64
# before:  545    0.0
# Name: HexType, dtype: float64
# after: 545    7.0
# Name: HexType, dtype: float64
# before:  2728    0.0
# Name: HexType, dtype: float64
# after: 2728    8.0
# Name: HexType, dtype: float64
# before:  3396    0.0
# Name: HexType, dtype: float64
# after: 3396    8.0
# Name: HexType, dtype: float64
# before:  5830    0.0
# Name: HexType, dtype: float64
# after: 5830    8.0
# Name: HexType, dtype: float64
# before:  813    0.0
# Name: HexType, dtype: float64
# after: 813    5.0
# Name: HexType, dtype: float64
# before:  4816    0.0
# Name: HexType, dtype: float64
# after: 4816    8.0
# Name: HexType, dtype: float64
# before:  9206    0.0
# Name: HexType, dtype: float64
# after: 9206    8.0
# Name: HexType, dtype: float64
# before:  9140    0.0
# Name: HexType, dtype: float64
# after: 9140    8.0
# Name: HexType, dtype: float64
# before:  8338    0.0
# Name: HexType, dtype: float64
# after: 8338    8.0
# Name: HexType, dtype: float64
# before:  1836    0.0
# Name: HexType, dtype: float64
# after: 1836    6.0
# Name: HexType, dtype: float64
# before:  5093    0.0
# Name: HexType, dtype: float64
# after: 5093    8.0
# Name: HexType, dtype: float64
# before:  2373    0.0
# Name: HexType, dtype: float64
# after: 2373    7.0
# Name: HexType, dtype: float64
# before:  8204    0.0
# Name: HexType, dtype: float64
# after: 8204    8.0
# Name: HexType, dtype: float64
# before:  9650    0.0
# Name: HexType, dtype: float64
# after: 9650    8.0
# Name: HexType, dtype: float64
# before:  4577    0.0
# Name: HexType, dtype: float64
# after: 4577    8.0
# Name: HexType, dtype: float64
# before:  10020    0.0
# Name: HexType, dtype: float64
# after: 10020    3.0
# Name: HexType, dtype: float64
# before:  6817    0.0
# Name: HexType, dtype: float64
# after: 6817    8.0
# Name: HexType, dtype: float64
# before:  8702    0.0
# Name: HexType, dtype: float64
# after: 8702    8.0
# Name: HexType, dtype: float64
# before:  2468    0.0
# Name: HexType, dtype: float64
# after: 2468    8.0
# Name: HexType, dtype: float64
# before:  9006    0.0
# Name: HexType, dtype: float64
# after: 9006    8.0
# Name: HexType, dtype: float64
# before:  6149    0.0
# Name: HexType, dtype: float64
# after: 6149    8.0
# Name: HexType, dtype: float64
# before:  554    0.0
# Name: HexType, dtype: float64
# after: 554    7.0
# Name: HexType, dtype: float64
# before:  7148    0.0
# Name: HexType, dtype: float64
# after: 7148    8.0
# Name: HexType, dtype: float64
# before:  9740    0.0
# Name: HexType, dtype: float64
# after: 9740    8.0
# Name: HexType, dtype: float64
# before:  9474    0.0
# Name: HexType, dtype: float64
# after: 9474    8.0
# Name: HexType, dtype: float64
# before:  6292    0.0
# Name: HexType, dtype: float64
# after: 6292    8.0
# Name: HexType, dtype: float64
# before:  6319    0.0
# Name: HexType, dtype: float64
# after: 6319    8.0
# Name: HexType, dtype: float64
# before:  4875    0.0
# Name: HexType, dtype: float64
# after: 4875    8.0
# Name: HexType, dtype: float64
# before:  8923    0.0
# Name: HexType, dtype: float64
# after: 8923    6.0
# Name: HexType, dtype: float64
# before:  2740    0.0
# Name: HexType, dtype: float64
# after: 2740    8.0
# Name: HexType, dtype: float64
# before:  6173    0.0
# Name: HexType, dtype: float64
# after: 6173    8.0
# Name: HexType, dtype: float64
# before:  214    0.0
# Name: HexType, dtype: float64
# after: 214    6.0
# Name: HexType, dtype: float64
# before:  9937    0.0
# Name: HexType, dtype: float64
# after: 9937    5.0
# Name: HexType, dtype: float64
# before:  8924    0.0
# Name: HexType, dtype: float64
# after: 8924    5.0
# Name: HexType, dtype: float64
# before:  264    0.0
# Name: HexType, dtype: float64
# after: 264    8.0
# Name: HexType, dtype: float64
# before:  9152    0.0
# Name: HexType, dtype: float64
# after: 9152    8.0
# Name: HexType, dtype: float64
# before:  1487    0.0
# Name: HexType, dtype: float64
# after: 1487    6.0
# Name: HexType, dtype: float64
# before:  8920    0.0
# Name: HexType, dtype: float64
# after: 8920    8.0
# Name: HexType, dtype: float64
# before:  551    0.0
# Name: HexType, dtype: float64
# after: 551    7.0
# Name: HexType, dtype: float64
# before:  1076    0.0
# Name: HexType, dtype: float64
# after: 1076    2.0
# Name: HexType, dtype: float64
# before:  9486    0.0
# Name: HexType, dtype: float64
# after: 9486    8.0
# Name: HexType, dtype: float64
# before:  5848    0.0
# Name: HexType, dtype: float64
# after: 5848    7.0
# Name: HexType, dtype: float64
# before:  3301    0.0
# Name: HexType, dtype: float64
# after: 3301    7.0
# Name: HexType, dtype: float64
# before:  7700    0.0
# Name: HexType, dtype: float64
# after: 7700    8.0
# Name: HexType, dtype: float64
# before:  4261    0.0
# Name: HexType, dtype: float64
# after: 4261    8.0
# Name: HexType, dtype: float64
# before:  253    0.0
# Name: HexType, dtype: float64
# after: 253    5.0
# Name: HexType, dtype: float64
# before:  8240    0.0
# Name: HexType, dtype: float64
# after: 8240    8.0
# Name: HexType, dtype: float64
# before:  3304    0.0
# Name: HexType, dtype: float64
# after: 3304    7.0
# Name: HexType, dtype: float64
# before:  6811    0.0
# Name: HexType, dtype: float64
# after: 6811    8.0
# Name: HexType, dtype: float64
# before:  4353    0.0
# Name: HexType, dtype: float64
# after: 4353    8.0
# Name: HexType, dtype: float64
# before:  8663    0.0
# Name: HexType, dtype: float64
# after: 8663    8.0
# Name: HexType, dtype: float64
# before:  3144    0.0
# Name: HexType, dtype: float64
# after: 3144    5.0
# Name: HexType, dtype: float64
# before:  5845    0.0
# Name: HexType, dtype: float64
# after: 5845    8.0
# Name: HexType, dtype: float64
# before:  54    0.0
# Name: HexType, dtype: float64
# after: 54    6.0
# Name: HexType, dtype: float64
# before:  2510    0.0
# Name: HexType, dtype: float64
# after: 2510    7.0
# Name: HexType, dtype: float64
# before:  8994    0.0
# Name: HexType, dtype: float64
# after: 8994    8.0
# Name: HexType, dtype: float64
# before:  3560    0.0
# Name: HexType, dtype: float64
# after: 3560    7.0
# Name: HexType, dtype: float64
# before:  9931    0.0
# Name: HexType, dtype: float64
# after: 9931    5.0
# Name: HexType, dtype: float64
# before:  992    0.0
# Name: HexType, dtype: float64
# after: 992    1.0
# Name: HexType, dtype: float64
# before:  2322    0.0
# Name: HexType, dtype: float64
# after: 2322    8.0
# Name: HexType, dtype: float64
# before:  718    0.0
# Name: HexType, dtype: float64
# after: 718    6.0
# Name: HexType, dtype: float64
# before:  7903    0.0
# Name: HexType, dtype: float64
# after: 7903    6.0
# Name: HexType, dtype: float64
# before:  4145    0.0
# Name: HexType, dtype: float64
# after: 4145    8.0
# Name: HexType, dtype: float64
# before:  3879    0.0
# Name: HexType, dtype: float64
# after: 3879    8.0
# Name: HexType, dtype: float64
# before:  5427    0.0
# Name: HexType, dtype: float64
# after: 5427    8.0
# Name: HexType, dtype: float64
# before:  7568    0.0
# Name: HexType, dtype: float64
# after: 7568    8.0
# Name: HexType, dtype: float64
# before:  8096    0.0
# Name: HexType, dtype: float64
# after: 8096    8.0
# Name: HexType, dtype: float64
# before:  4607    0.0
# Name: HexType, dtype: float64
# after: 4607    8.0
# Name: HexType, dtype: float64
# before:  3035    0.0
# Name: HexType, dtype: float64
# after: 3035    7.0
# Name: HexType, dtype: float64
# before:  4529    0.0
# Name: HexType, dtype: float64
# after: 4529    8.0
# Name: HexType, dtype: float64
# before:  211    0.0
# Name: HexType, dtype: float64
# after: 211    8.0
# Name: HexType, dtype: float64
# before:  7091    0.0
# Name: HexType, dtype: float64
# after: 7091    8.0
# Name: HexType, dtype: float64
# before:  315    0.0
# Name: HexType, dtype: float64
# after: 315    4.0
# Name: HexType, dtype: float64
# before:  3995    0.0
# Name: HexType, dtype: float64
# after: 3995    5.0
# Name: HexType, dtype: float64
# before:  1219    0.0
# Name: HexType, dtype: float64
# after: 1219    6.0
# Name: HexType, dtype: float64
# before:  6334    0.0
# Name: HexType, dtype: float64
# after: 6334    8.0
# Name: HexType, dtype: float64
# before:  5558    0.0
# Name: HexType, dtype: float64
# after: 5558    8.0
# Name: HexType, dtype: float64
# before:  3360    0.0
# Name: HexType, dtype: float64
# after: 3360    8.0
# Name: HexType, dtype: float64
# before:  6930    0.0
# Name: HexType, dtype: float64
# after: 6930    8.0
# Name: HexType, dtype: float64
# before:  8967    0.0
# Name: HexType, dtype: float64
# after: 8967    8.0
# Name: HexType, dtype: float64
# before:  8705    0.0
# Name: HexType, dtype: float64
# after: 8705    8.0
# Name: HexType, dtype: float64
# before:  4828    0.0
# Name: HexType, dtype: float64
# after: 4828    8.0
# Name: HexType, dtype: float64
# before:  72    0.0
# Name: HexType, dtype: float64
# after: 72    4.0
# Name: HexType, dtype: float64
# before:  7387    0.0
# Name: HexType, dtype: float64
# after: 7387    8.0
# Name: HexType, dtype: float64
# before:  7175    0.0
# Name: HexType, dtype: float64
# after: 7175    8.0
# Name: HexType, dtype: float64
# before:  724    0.0
# Name: HexType, dtype: float64
# after: 724    6.0
# Name: HexType, dtype: float64
# before:  7944    0.0
# Name: HexType, dtype: float64
# after: 7944    8.0
# Name: HexType, dtype: float64
# before:  297    0.0
# Name: HexType, dtype: float64
# after: 297    7.0
# Name: HexType, dtype: float64
# before:  8591    0.0
# Name: HexType, dtype: float64
# after: 8591    8.0
# Name: HexType, dtype: float64
# before:  9263    0.0
# Name: HexType, dtype: float64
# after: 9263    6.0
# Name: HexType, dtype: float64
# before:  1538    0.0
# Name: HexType, dtype: float64
# after: 1538    8.0
# Name: HexType, dtype: float64
# before:  5317    0.0
# Name: HexType, dtype: float64
# after: 5317    8.0
# Name: HexType, dtype: float64
# before:  9951    0.0
# Name: HexType, dtype: float64
# after: 9951    3.0
# Name: HexType, dtype: float64
# before:  4324    0.0
# Name: HexType, dtype: float64
# after: 4324    8.0
# Name: HexType, dtype: float64
# before:  9170    0.0
# Name: HexType, dtype: float64
# after: 9170    8.0
# Name: HexType, dtype: float64
# before:  5588    0.0
# Name: HexType, dtype: float64
# after: 5588    8.0
# Name: HexType, dtype: float64
# before:  1454    0.0
# Name: HexType, dtype: float64
# after: 1454    8.0
# Name: HexType, dtype: float64
# before:  3843    0.0
# Name: HexType, dtype: float64
# after: 3843    8.0
# Name: HexType, dtype: float64
# before:  792    0.0
# Name: HexType, dtype: float64
# after: 792    6.0
# Name: HexType, dtype: float64
# before:  8472    0.0
# Name: HexType, dtype: float64
# after: 8472    8.0
# Name: HexType, dtype: float64
# before:  584    0.0
# Name: HexType, dtype: float64
# after: 584    5.0
# Name: HexType, dtype: float64
# before:  6047    0.0
# Name: HexType, dtype: float64
# after: 6047    8.0
# Name: HexType, dtype: float64
# before:  8377    0.0
# Name: HexType, dtype: float64
# after: 8377    8.0
# Name: HexType, dtype: float64
# before:  6092    0.0
# Name: HexType, dtype: float64
# after: 6092    8.0
# Name: HexType, dtype: float64
# before:  178    0.0
# Name: HexType, dtype: float64
# after: 178    8.0
# Name: HexType, dtype: float64
# before:  8937    0.0
# Name: HexType, dtype: float64
# after: 8937    8.0
# Name: HexType, dtype: float64
# before:  8356    0.0
# Name: HexType, dtype: float64
# after: 8356    8.0
# Name: HexType, dtype: float64
# before:  2838    0.0
# Name: HexType, dtype: float64
# after: 2838    8.0
# Name: HexType, dtype: float64
# before:  7154    0.0
# Name: HexType, dtype: float64
# after: 7154    8.0
# Name: HexType, dtype: float64
# before:  6399    0.0
# Name: HexType, dtype: float64
# after: 6399    8.0
# Name: HexType, dtype: float64
# before:  1982    0.0
# Name: HexType, dtype: float64
# after: 1982    8.0
# Name: HexType, dtype: float64
# before:  1299    0.0
# Name: HexType, dtype: float64
# after: 1299    7.0
# Name: HexType, dtype: float64
# before:  1264    0.0
# Name: HexType, dtype: float64
# after: 1264    5.0
# Name: HexType, dtype: float64
# before:  506    0.0
# Name: HexType, dtype: float64
# after: 506    6.0
# Name: HexType, dtype: float64
# before:  7109    0.0
# Name: HexType, dtype: float64
# after: 7109    8.0
# Name: HexType, dtype: float64
# before:  6188    0.0
# Name: HexType, dtype: float64
# after: 6188    7.0
# Name: HexType, dtype: float64
# before:  6900    0.0
# Name: HexType, dtype: float64
# after: 6900    8.0
# Name: HexType, dtype: float64
# before:  539    0.0
# Name: HexType, dtype: float64
# after: 539    5.0
# Name: HexType, dtype: float64
# before:  4926    0.0
# Name: HexType, dtype: float64
# after: 4926    8.0
# Name: HexType, dtype: float64
# before:  2785    0.0
# Name: HexType, dtype: float64
# after: 2785    6.0
# Name: HexType, dtype: float64
# before:  2269    0.0
# Name: HexType, dtype: float64
# after: 2269    5.0
# Name: HexType, dtype: float64
# before:  6444    0.0
# Name: HexType, dtype: float64
# after: 6444    6.0
# Name: HexType, dtype: float64
# before:  4371    0.0
# Name: HexType, dtype: float64
# after: 4371    8.0
# Name: HexType, dtype: float64
# before:  2516    0.0
# Name: HexType, dtype: float64
# after: 2516    6.0
# Name: HexType, dtype: float64
# before:  9400    0.0
# Name: HexType, dtype: float64
# after: 9400    8.0
# Name: HexType, dtype: float64
# before:  7378    0.0
# Name: HexType, dtype: float64
# after: 7378    7.0
# Name: HexType, dtype: float64
# before:  4837    0.0
# Name: HexType, dtype: float64
# after: 4837    8.0
# Name: HexType, dtype: float64
# before:  6355    0.0
# Name: HexType, dtype: float64
# after: 6355    7.0
# Name: HexType, dtype: float64
# before:  5907    0.0
# Name: HexType, dtype: float64
# after: 5907    8.0
# Name: HexType, dtype: float64
# before:  6805    0.0
# Name: HexType, dtype: float64
# after: 6805    8.0
# Name: HexType, dtype: float64
# before:  8654    0.0
# Name: HexType, dtype: float64
# after: 8654    8.0
# Name: HexType, dtype: float64
# before:  3566    0.0
# Name: HexType, dtype: float64
# after: 3566    8.0
# Name: HexType, dtype: float64
# before:  9    0.0
# Name: HexType, dtype: float64
# after: 9    8.0
# Name: HexType, dtype: float64
# before:  3876    0.0
# Name: HexType, dtype: float64
# after: 3876    8.0
# Name: HexType, dtype: float64
# before:  5341    0.0
# Name: HexType, dtype: float64
# after: 5341    8.0
# Name: HexType, dtype: float64
# before:  7861    0.0
# Name: HexType, dtype: float64
# after: 7861    8.0
# Name: HexType, dtype: float64
# before:  7628    0.0
# Name: HexType, dtype: float64
# after: 7628    8.0
# Name: HexType, dtype: float64
# before:  9498    0.0
# Name: HexType, dtype: float64
# after: 9498    8.0
# Name: HexType, dtype: float64
# before:  8427    0.0
# Name: HexType, dtype: float64
# after: 8427    8.0
# Name: HexType, dtype: float64
# before:  4097    0.0
# Name: HexType, dtype: float64
# after: 4097    8.0
# Name: HexType, dtype: float64
# before:  7834    0.0
# Name: HexType, dtype: float64
# after: 7834    8.0
# Name: HexType, dtype: float64
# before:  5021    0.0
# Name: HexType, dtype: float64
# after: 5021    8.0
# Name: HexType, dtype: float64
# before:  6182    0.0
# Name: HexType, dtype: float64
# after: 6182    8.0
# Name: HexType, dtype: float64
# before:  5421    0.0
# Name: HexType, dtype: float64
# after: 5421    8.0
# Name: HexType, dtype: float64
# before:  8618    0.0
# Name: HexType, dtype: float64
# after: 8618    8.0
# Name: HexType, dtype: float64
# before:  9611    0.0
# Name: HexType, dtype: float64
# after: 9611    8.0
# Name: HexType, dtype: float64
# before:  9608    0.0
# Name: HexType, dtype: float64
# after: 9608    8.0
# Name: HexType, dtype: float64
# before:  5361    0.0
# Name: HexType, dtype: float64
# after: 5361    8.0
# Name: HexType, dtype: float64
# before:  563    0.0
# Name: HexType, dtype: float64
# after: 563    5.0
# Name: HexType, dtype: float64
# before:  4288    0.0
# Name: HexType, dtype: float64
# after: 4288    8.0
# Name: HexType, dtype: float64
# before:  9435    0.0
# Name: HexType, dtype: float64
# after: 9435    5.0
# Name: HexType, dtype: float64
# before:  8726    0.0
# Name: HexType, dtype: float64
# after: 8726    8.0
# Name: HexType, dtype: float64
# before:  324    0.0
# Name: HexType, dtype: float64
# after: 324    3.0
# Name: HexType, dtype: float64
# before:  8627    0.0
# Name: HexType, dtype: float64
# after: 8627    8.0
# Name: HexType, dtype: float64
# before:  8180    0.0
# Name: HexType, dtype: float64
# after: 8180    8.0
# Name: HexType, dtype: float64
# before:  7190    0.0
# Name: HexType, dtype: float64
# after: 7190    8.0
# Name: HexType, dtype: float64
# before:  4154    0.0
# Name: HexType, dtype: float64
# after: 4154    8.0
# Name: HexType, dtype: float64
# before:  3784    0.0
# Name: HexType, dtype: float64
# after: 3784    8.0
# Name: HexType, dtype: float64
# before:  6888    0.0
# Name: HexType, dtype: float64
# after: 6888    8.0
# Name: HexType, dtype: float64
# before:  1726    0.0
# Name: HexType, dtype: float64
# after: 1726    8.0
# Name: HexType, dtype: float64
# before:  521    0.0
# Name: HexType, dtype: float64
# after: 521    8.0
# Name: HexType, dtype: float64
# before:  998    0.0
# Name: HexType, dtype: float64
# after: 998    1.0
# Name: HexType, dtype: float64
# before:  2621    0.0
# Name: HexType, dtype: float64
# after: 2621    6.0
# Name: HexType, dtype: float64
# before:  6158    0.0
# Name: HexType, dtype: float64
# after: 6158    8.0
# Name: HexType, dtype: float64
# before:  3590    0.0
# Name: HexType, dtype: float64
# after: 3590    8.0
# Name: HexType, dtype: float64
# before:  4270    0.0
# Name: HexType, dtype: float64
# after: 4270    8.0
# Name: HexType, dtype: float64
# before:  6850    0.0
# Name: HexType, dtype: float64
# after: 6850    8.0
# Name: HexType, dtype: float64
# before:  6912    0.0
# Name: HexType, dtype: float64
# after: 6912    8.0
# Name: HexType, dtype: float64
# before:  3654    0.0
# Name: HexType, dtype: float64
# after: 3654    5.0
# Name: HexType, dtype: float64
# before:  6844    0.0
# Name: HexType, dtype: float64
# after: 6844    8.0
# Name: HexType, dtype: float64
# before:  184    0.0
# Name: HexType, dtype: float64
# after: 184    8.0
# Name: HexType, dtype: float64
# before:  4807    0.0
# Name: HexType, dtype: float64
# after: 4807    8.0
# Name: HexType, dtype: float64
# before:  187    0.0
# Name: HexType, dtype: float64
# after: 187    7.0
# Name: HexType, dtype: float64
# before:  760    0.0
# Name: HexType, dtype: float64
# after: 760    6.0
# Name: HexType, dtype: float64
# before:  1261    0.0
# Name: HexType, dtype: float64
# after: 1261    2.0
# Name: HexType, dtype: float64
# before:  5054    0.0
# Name: HexType, dtype: float64
# after: 5054    8.0
# Name: HexType, dtype: float64
# before:  1445    0.0
# Name: HexType, dtype: float64
# after: 1445    5.0
# Name: HexType, dtype: float64
# before:  5827    0.0
# Name: HexType, dtype: float64
# after: 5827    8.0
# Name: HexType, dtype: float64
# before:  3563    0.0
# Name: HexType, dtype: float64
# after: 3563    8.0
# Name: HexType, dtype: float64
# before:  3110    0.0
# Name: HexType, dtype: float64
# after: 3110    7.0
# Name: HexType, dtype: float64
# before:  9944    0.0
# Name: HexType, dtype: float64
# after: 9944    5.0
# Name: HexType, dtype: float64
# before:  175    0.0
# Name: HexType, dtype: float64
# after: 175    8.0
# Name: HexType, dtype: float64
# before:  6656    0.0
# Name: HexType, dtype: float64
# after: 6656    8.0
# Name: HexType, dtype: float64
# before:  4157    0.0
# Name: HexType, dtype: float64
# after: 4157    8.0
# Name: HexType, dtype: float64
# before:  5180    0.0
# Name: HexType, dtype: float64
# after: 5180    8.0
# Name: HexType, dtype: float64
# before:  840    0.0
# Name: HexType, dtype: float64
# after: 840    6.0
# Name: HexType, dtype: float64
# before:  7458    0.0
# Name: HexType, dtype: float64
# after: 7458    7.0
# Name: HexType, dtype: float64
# before:  8433    0.0
# Name: HexType, dtype: float64
# after: 8433    8.0
# Name: HexType, dtype: float64
# before:  2579    0.0
# Name: HexType, dtype: float64
# after: 2579    8.0
# Name: HexType, dtype: float64
# before:  983    0.0
# Name: HexType, dtype: float64
# after: 983    5.0
# Name: HexType, dtype: float64
# before:  6074    0.0
# Name: HexType, dtype: float64
# after: 6074    8.0
# Name: HexType, dtype: float64
# before:  7959    0.0
# Name: HexType, dtype: float64
# after: 7959    8.0
# Name: HexType, dtype: float64
# before:  9376    0.0
# Name: HexType, dtype: float64
# after: 9376    8.0
# Name: HexType, dtype: float64
# before:  6450    0.0
# Name: HexType, dtype: float64
# after: 6450    8.0
# Name: HexType, dtype: float64
# before:  2066    0.0
# Name: HexType, dtype: float64
# after: 2066    8.0
# Name: HexType, dtype: float64
# before:  2260    0.0
# Name: HexType, dtype: float64
# after: 2260    7.0
# Name: HexType, dtype: float64
# before:  7172    0.0
# Name: HexType, dtype: float64
# after: 7172    8.0
# Name: HexType, dtype: float64
# before:  703    0.0
# Name: HexType, dtype: float64
# after: 703    6.0
# Name: HexType, dtype: float64
# before:  947    0.0
# Name: HexType, dtype: float64
# after: 947    8.0
# Name: HexType, dtype: float64
# before:  8424    0.0
# Name: HexType, dtype: float64
# after: 8424    8.0
# Name: HexType, dtype: float64
# before:  2835    0.0
# Name: HexType, dtype: float64
# after: 2835    8.0
# Name: HexType, dtype: float64
# before:  2804    0.0
# Name: HexType, dtype: float64
# after: 2804    5.0
# Name: HexType, dtype: float64
# before:  8866    0.0
# Name: HexType, dtype: float64
# after: 8866    8.0
# Name: HexType, dtype: float64
# before:  2358    0.0
# Name: HexType, dtype: float64
# after: 2358    6.0
# Name: HexType, dtype: float64
# before:  9907    0.0
# Name: HexType, dtype: float64
# after: 9907    5.0
# Name: HexType, dtype: float64
# before:  8460    0.0
# Name: HexType, dtype: float64
# after: 8460    8.0
# Name: HexType, dtype: float64
# before:  300    0.0
# Name: HexType, dtype: float64
# after: 300    6.0
# Name: HexType, dtype: float64
# before:  5818    0.0
# Name: HexType, dtype: float64
# after: 5818    8.0
# Name: HexType, dtype: float64
# before:  2814    0.0
# Name: HexType, dtype: float64
# after: 2814    8.0
# Name: HexType, dtype: float64
# before:  8228    0.0
# Name: HexType, dtype: float64
# after: 8228    8.0
# Name: HexType, dtype: float64
# before:  4674    0.0
# Name: HexType, dtype: float64
# after: 4674    5.0
# Name: HexType, dtype: float64
# before:  1305    0.0
# Name: HexType, dtype: float64
# after: 1305    7.0
# Name: HexType, dtype: float64
# before:  5898    0.0
# Name: HexType, dtype: float64
# after: 5898    8.0
# Name: HexType, dtype: float64
# before:  9104    0.0
# Name: HexType, dtype: float64
# after: 9104    8.0
# Name: HexType, dtype: float64
# before:  6304    0.0
# Name: HexType, dtype: float64
# after: 6304    8.0
# Name: HexType, dtype: float64
# before:  5600    0.0
# Name: HexType, dtype: float64
# after: 5600    8.0
# Name: HexType, dtype: float64
# before:  3861    0.0
# Name: HexType, dtype: float64
# after: 3861    8.0
# Name: HexType, dtype: float64
# before:  3825    0.0
# Name: HexType, dtype: float64
# after: 3825    5.0
# Name: HexType, dtype: float64
# before:  491    0.0
# Name: HexType, dtype: float64
# after: 491    2.0
# Name: HexType, dtype: float64
# before:  6945    0.0
# Name: HexType, dtype: float64
# after: 6945    8.0
# Name: HexType, dtype: float64
# before:  8908    0.0
# Name: HexType, dtype: float64
# after: 8908    8.0
# Name: HexType, dtype: float64
# before:  9441    0.0
# Name: HexType, dtype: float64
# after: 9441    8.0
# Name: HexType, dtype: float64
# before:  8484    8.0
# Name: HexType, dtype: float64
# after: 8484    8.0
# Name: HexType, dtype: float64
# before:  8714    0.0
# Name: HexType, dtype: float64
# after: 8714    8.0
# Name: HexType, dtype: float64
# before:  1207    0.0
# Name: HexType, dtype: float64
# after: 1207    8.0
# Name: HexType, dtype: float64
# before:  3855    0.0
# Name: HexType, dtype: float64
# after: 3855    8.0
# Name: HexType, dtype: float64
# before:  6626    0.0
# Name: HexType, dtype: float64
# after: 6626    8.0
# Name: HexType, dtype: float64
# before:  843    0.0
# Name: HexType, dtype: float64
# after: 843    4.0
# Name: HexType, dtype: float64
# before:  2075    0.0
# Name: HexType, dtype: float64
# after: 2075    8.0
# Name: HexType, dtype: float64
# before:  9984    0.0
# Name: HexType, dtype: float64
# after: 9984    3.0
# Name: HexType, dtype: float64
# before:  1007    0.0
# Name: HexType, dtype: float64
# after: 1007    4.0
# Name: HexType, dtype: float64
# before:  6387    0.0
# Name: HexType, dtype: float64
# after: 6387    8.0
# Name: HexType, dtype: float64
# before:  786    0.0
# Name: HexType, dtype: float64
# after: 786    7.0
# Name: HexType, dtype: float64
# before:  3104    0.0
# Name: HexType, dtype: float64
# after: 3104    8.0
# Name: HexType, dtype: float64
# before:  9653    0.0
# Name: HexType, dtype: float64
# after: 9653    8.0
# Name: HexType, dtype: float64
# before:  5338    0.0
# Name: HexType, dtype: float64
# after: 5338    8.0
# Name: HexType, dtype: float64
# before:  5147    0.0
# Name: HexType, dtype: float64
# after: 5147    8.0
# Name: HexType, dtype: float64
# before:  1514    0.0
# Name: HexType, dtype: float64
# after: 1514    3.0
# Name: HexType, dtype: float64
# before:  9158    0.0
# Name: HexType, dtype: float64
# after: 9158    8.0
# Name: HexType, dtype: float64
# before:  2239    0.0
# Name: HexType, dtype: float64
# after: 2239    8.0
# Name: HexType, dtype: float64
# before:  2495    0.0
# Name: HexType, dtype: float64
# after: 2495    8.0
# Name: HexType, dtype: float64
# before:  7730    0.0
# Name: HexType, dtype: float64
# after: 7730    8.0
# Name: HexType, dtype: float64
# before:  5332    0.0
# Name: HexType, dtype: float64
# after: 5332    8.0
# Name: HexType, dtype: float64
# before:  5048    0.0
# Name: HexType, dtype: float64
# after: 5048    8.0
# Name: HexType, dtype: float64
# before:  9504    0.0
# Name: HexType, dtype: float64
# after: 9504    8.0
# Name: HexType, dtype: float64
# before:  569    0.0
# Name: HexType, dtype: float64
# after: 569    2.0
# Name: HexType, dtype: float64
# before:  2123    0.0
# Name: HexType, dtype: float64
# after: 2123    6.0
# Name: HexType, dtype: float64
# before:  6414    0.0
# Name: HexType, dtype: float64
# after: 6414    8.0
# Name: HexType, dtype: float64
# before:  7324    0.0
# Name: HexType, dtype: float64
# after: 7324    8.0
# Name: HexType, dtype: float64
# before:  1797    0.0
# Name: HexType, dtype: float64
# after: 1797    8.0
# Name: HexType, dtype: float64
# before:  1204    0.0
# Name: HexType, dtype: float64
# after: 1204    8.0
# Name: HexType, dtype: float64
# before:  8684    0.0
# Name: HexType, dtype: float64
# after: 8684    8.0
# Name: HexType, dtype: float64
# before:  8729    0.0
# Name: HexType, dtype: float64
# after: 8729    8.0
# Name: HexType, dtype: float64
# before:  5305    0.0
# Name: HexType, dtype: float64
# after: 5305    8.0
# Name: HexType, dtype: float64
# before:  9370    0.0
# Name: HexType, dtype: float64
# after: 9370    8.0
# Name: HexType, dtype: float64
# before:  333    0.0
# Name: HexType, dtype: float64
# after: 333    6.0
# Name: HexType, dtype: float64
# before:  3885    0.0
# Name: HexType, dtype: float64
# after: 3885    8.0
# Name: HexType, dtype: float64
# before:  9874    0.0
# Name: HexType, dtype: float64
# after: 9874    5.0
# Name: HexType, dtype: float64
# before:  1997    0.0
# Name: HexType, dtype: float64
# after: 1997    7.0
# Name: HexType, dtype: float64
# before:  1100    0.0
# Name: HexType, dtype: float64
# after: 1100    6.0
# Name: HexType, dtype: float64
# before:  3074    0.0
# Name: HexType, dtype: float64
# after: 3074    8.0
# Name: HexType, dtype: float64
# before:  819    0.0
# Name: HexType, dtype: float64
# after: 819    3.0
# Name: HexType, dtype: float64
# before:  8448    0.0
# Name: HexType, dtype: float64
# after: 8448    8.0
# Name: HexType, dtype: float64
# before:  9734    0.0
# Name: HexType, dtype: float64
# after: 9734    8.0
# Name: HexType, dtype: float64
# before:  7372    0.0
# Name: HexType, dtype: float64
# after: 7372    8.0
# Name: HexType, dtype: float64
# before:  8126    0.0
# Name: HexType, dtype: float64
# after: 8126    8.0
# Name: HexType, dtype: float64
# before:  9883    0.0
# Name: HexType, dtype: float64
# after: 9883    5.0
# Name: HexType, dtype: float64
# before:  3488    0.0
# Name: HexType, dtype: float64
# after: 3488    8.0
# Name: HexType, dtype: float64
# before:  3023    0.0
# Name: HexType, dtype: float64
# after: 3023    8.0
# Name: HexType, dtype: float64
# before:  4151    0.0
# Name: HexType, dtype: float64
# after: 4151    8.0
# Name: HexType, dtype: float64
# before:  8988    0.0
# Name: HexType, dtype: float64
# after: 8988    8.0
# Name: HexType, dtype: float64
# before:  2325    0.0
# Name: HexType, dtype: float64
# after: 2325    8.0
# Name: HexType, dtype: float64
# before:  7974    0.0
# Name: HexType, dtype: float64
# after: 7974    8.0
# Name: HexType, dtype: float64
# before:  8395    0.0
# Name: HexType, dtype: float64
# after: 8395    8.0
# Name: HexType, dtype: float64
# before:  467    0.0
# Name: HexType, dtype: float64
# after: 467    6.0
# Name: HexType, dtype: float64
# before:  3745    0.0
# Name: HexType, dtype: float64
# after: 3745    8.0
# Name: HexType, dtype: float64
# before:  2725    0.0
# Name: HexType, dtype: float64
# after: 2725    8.0
# Name: HexType, dtype: float64
# before:  7968    0.0
# Name: HexType, dtype: float64
# after: 7968    8.0
# Name: HexType, dtype: float64
# before:  6838    0.0
# Name: HexType, dtype: float64
# after: 6838    8.0
# Name: HexType, dtype: float64
# before:  4356    0.0
# Name: HexType, dtype: float64
# after: 4356    8.0
# Name: HexType, dtype: float64
# before:  1833    0.0
# Name: HexType, dtype: float64
# after: 1833    6.0
# Name: HexType, dtype: float64
# before:  1735    0.0
# Name: HexType, dtype: float64
# after: 1735    8.0
# Name: HexType, dtype: float64
# before:  3644    0.0
# Name: HexType, dtype: float64
# after: 3644    7.0
# Name: HexType, dtype: float64
# before:  21    0.0
# Name: HexType, dtype: float64
# after: 21    7.0
# Name: HexType, dtype: float64
# before:  3653    0.0
# Name: HexType, dtype: float64
# after: 3653    6.0
# Name: HexType, dtype: float64
# before:  3038    0.0
# Name: HexType, dtype: float64
# after: 3038    6.0
# Name: HexType, dtype: float64
# before:  5069    0.0
# Name: HexType, dtype: float64
# after: 5069    8.0
# Name: HexType, dtype: float64
# before:  9632    0.0
# Name: HexType, dtype: float64
# after: 9632    8.0
# Name: HexType, dtype: float64
# before:  6659    0.0
# Name: HexType, dtype: float64
# after: 6659    8.0
# Name: HexType, dtype: float64
# before:  5871    0.0
# Name: HexType, dtype: float64
# after: 5871    8.0
# Name: HexType, dtype: float64
# before:  721    0.0
# Name: HexType, dtype: float64
# after: 721    6.0
# Name: HexType, dtype: float64
# before:  6101    0.0
# Name: HexType, dtype: float64
# after: 6101    7.0
# Name: HexType, dtype: float64
# before:  9164    0.0
# Name: HexType, dtype: float64
# after: 9164    8.0
# Name: HexType, dtype: float64
# before:  4655    0.0
# Name: HexType, dtype: float64
# after: 4655    8.0
# Name: HexType, dtype: float64
# before:  1708    0.0
# Name: HexType, dtype: float64
# after: 1708    8.0
# Name: HexType, dtype: float64
# before:  9456    0.0
# Name: HexType, dtype: float64
# after: 9456    8.0
# Name: HexType, dtype: float64
# before:  8949    0.0
# Name: HexType, dtype: float64
# after: 8949    8.0
# Name: HexType, dtype: float64
# before:  7956    0.0
# Name: HexType, dtype: float64
# after: 7956    8.0
# Name: HexType, dtype: float64
# before:  7709    0.0
# Name: HexType, dtype: float64
# after: 7709    8.0
# Name: HexType, dtype: float64
# before:  6587    0.0
# Name: HexType, dtype: float64
# after: 6587    8.0
# Name: HexType, dtype: float64
# before:  2251    0.0
# Name: HexType, dtype: float64
# after: 2251    8.0
# Name: HexType, dtype: float64
# before:  575    0.0
# Name: HexType, dtype: float64
# after: 575    1.0
# Name: HexType, dtype: float64
# before:  9752    0.0
# Name: HexType, dtype: float64
# after: 9752    8.0
# Name: HexType, dtype: float64
# before:  5063    0.0
# Name: HexType, dtype: float64
# after: 5063    8.0
# Name: HexType, dtype: float64
# before:  7986    0.0
# Name: HexType, dtype: float64
# after: 7986    8.0
# Name: HexType, dtype: float64
# before:  431    0.0
# Name: HexType, dtype: float64
# after: 431    8.0
# Name: HexType, dtype: float64
# before:  8481    0.0
# Name: HexType, dtype: float64
# after: 8481    8.0
# Name: HexType, dtype: float64
# before:  4920    0.0
# Name: HexType, dtype: float64
# after: 4920    8.0
# Name: HexType, dtype: float64
# before:  1031    0.0
# Name: HexType, dtype: float64
# after: 1031    8.0
# Name: HexType, dtype: float64
# before:  5606    0.0
# Name: HexType, dtype: float64
# after: 5606    8.0
# Name: HexType, dtype: float64
# before:  6906    0.0
# Name: HexType, dtype: float64
# after: 6906    8.0
# Name: HexType, dtype: float64
# before:  3354    0.0
# Name: HexType, dtype: float64
# after: 3354    8.0
# Name: HexType, dtype: float64
# before:  7625    0.0
# Name: HexType, dtype: float64
# after: 7625    8.0
# Name: HexType, dtype: float64
# before:  1004    0.0
# Name: HexType, dtype: float64
# after: 1004    3.0
# Name: HexType, dtype: float64
# before:  8851    0.0
# Name: HexType, dtype: float64
# after: 8851    8.0
# Name: HexType, dtype: float64
# before:  4163    0.0
# Name: HexType, dtype: float64
# after: 4163    6.0
# Name: HexType, dtype: float64
# before:  5153    0.0
# Name: HexType, dtype: float64
# after: 5153    8.0
# Name: HexType, dtype: float64
# before:  2782    0.0
# Name: HexType, dtype: float64
# after: 2782    6.0
# Name: HexType, dtype: float64
# before:  712    0.0
# Name: HexType, dtype: float64
# after: 712    6.0
# Name: HexType, dtype: float64
# before:  789    0.0
# Name: HexType, dtype: float64
# after: 789    6.0
# Name: HexType, dtype: float64
# before:  4359    0.0
# Name: HexType, dtype: float64
# after: 4359    8.0
# Name: HexType, dtype: float64
# before:  709    0.0
# Name: HexType, dtype: float64
# after: 709    6.0
# Name: HexType, dtype: float64
# before:  4285    0.0
# Name: HexType, dtype: float64
# after: 4285    8.0
# Name: HexType, dtype: float64
# before:  9146    0.0
# Name: HexType, dtype: float64
# after: 9146    8.0
# Name: HexType, dtype: float64
# before:  4255    0.0
# Name: HexType, dtype: float64
# after: 4255    8.0
# Name: HexType, dtype: float64
# before:  5081    0.0
# Name: HexType, dtype: float64
# after: 5081    8.0
# Name: HexType, dtype: float64
# before:  30    0.0
# Name: HexType, dtype: float64
# after: 30    5.0
# Name: HexType, dtype: float64
# before:  5857    0.0
# Name: HexType, dtype: float64
# after: 5857    8.0
# Name: HexType, dtype: float64
# before:  9095    0.0
# Name: HexType, dtype: float64
# after: 9095    5.0
# Name: HexType, dtype: float64
# before:  443    0.0
# Name: HexType, dtype: float64
# after: 443    7.0
# Name: HexType, dtype: float64
# before:  452    0.0
# Name: HexType, dtype: float64
# after: 452    4.0
# Name: HexType, dtype: float64
# before:  5057    0.0
# Name: HexType, dtype: float64
# after: 5057    8.0
# Name: HexType, dtype: float64
# before:  4613    0.0
# Name: HexType, dtype: float64
# after: 4613    8.0
# Name: HexType, dtype: float64
# before:  1857    0.0
# Name: HexType, dtype: float64
# after: 1857    5.0
# Name: HexType, dtype: float64
# before:  3375    0.0
# Name: HexType, dtype: float64
# after: 3375    7.0
# Name: HexType, dtype: float64
# before:  9647    0.0
# Name: HexType, dtype: float64
# after: 9647    8.0
# Name: HexType, dtype: float64
# before:  1472    0.0
# Name: HexType, dtype: float64
# after: 1472    7.0
# Name: HexType, dtype: float64
# before:  688    0.0
# Name: HexType, dtype: float64
# after: 688    8.0
# Name: HexType, dtype: float64
# before:  500    0.0
# Name: HexType, dtype: float64
# after: 500    6.0
# Name: HexType, dtype: float64
# before:  336    0.0
# Name: HexType, dtype: float64
# after: 336    7.0
# Name: HexType, dtype: float64
# before:  3065    0.0
# Name: HexType, dtype: float64
# after: 3065    8.0
# Name: HexType, dtype: float64
# before:  6647    0.0
# Name: HexType, dtype: float64
# after: 6647    8.0
# Name: HexType, dtype: float64
# before:  6948    0.0
# Name: HexType, dtype: float64
# after: 6948    7.0
# Name: HexType, dtype: float64
# before:  5883    0.0
# Name: HexType, dtype: float64
# after: 5883    8.0
# Name: HexType, dtype: float64
# before:  2591    0.0
# Name: HexType, dtype: float64
# after: 2591    8.0
# Name: HexType, dtype: float64
# before:  1863    0.0
# Name: HexType, dtype: float64
# after: 1863    5.0
# Name: HexType, dtype: float64
# before:  1780    0.0
# Name: HexType, dtype: float64
# after: 1780    6.0
# Name: HexType, dtype: float64
# before:  9471    0.0
# Name: HexType, dtype: float64
# after: 9471    8.0
# Name: HexType, dtype: float64
# before:  5364    0.0
# Name: HexType, dtype: float64
# after: 5364    8.0
# Name: HexType, dtype: float64
# before:  7085    0.0
# Name: HexType, dtype: float64
# after: 7085    8.0
# Name: HexType, dtype: float64
# before:  4911    0.0
# Name: HexType, dtype: float64
# after: 4911    8.0
# Name: HexType, dtype: float64
# before:  518    0.0
# Name: HexType, dtype: float64
# after: 518    8.0
# Name: HexType, dtype: float64
# before:  9421    0.0
# Name: HexType, dtype: float64
# after: 9421    8.0
# Name: HexType, dtype: float64
# before:  476    0.0
# Name: HexType, dtype: float64
# after: 476    6.0
# Name: HexType, dtype: float64
# before:  4893    0.0
# Name: HexType, dtype: float64
# after: 4893    8.0
# Name: HexType, dtype: float64
# before:  1043    0.0
# Name: HexType, dtype: float64
# after: 1043    6.0
# Name: HexType, dtype: float64
# before:  6367    0.0
# Name: HexType, dtype: float64
# after: 6367    7.0
# Name: HexType, dtype: float64
# before:  834    0.0
# Name: HexType, dtype: float64
# after: 834    2.0
# Name: HexType, dtype: float64
# before:  1550    0.0
# Name: HexType, dtype: float64
# after: 1550    8.0
# Name: HexType, dtype: float64
# before:  2504    0.0
# Name: HexType, dtype: float64
# after: 2504    8.0
# Name: HexType, dtype: float64
# before:  9659    0.0
# Name: HexType, dtype: float64
# after: 9659    8.0
# Name: HexType, dtype: float64
# before:  4365    0.0
# Name: HexType, dtype: float64
# after: 4365    8.0
# Name: HexType, dtype: float64
# before:  2328    0.0
# Name: HexType, dtype: float64
# after: 2328    8.0
# Name: HexType, dtype: float64
# before:  8192    0.0
# Name: HexType, dtype: float64
# after: 8192    8.0
# Name: HexType, dtype: float64
# before:  5350    0.0
# Name: HexType, dtype: float64
# after: 5350    8.0
# Name: HexType, dtype: float64
# before:  2808    0.0
# Name: HexType, dtype: float64
# after: 2808    8.0
# Name: HexType, dtype: float64
# before:  2594    0.0
# Name: HexType, dtype: float64
# after: 2594    7.0
# Name: HexType, dtype: float64
# before:  1192    0.0
# Name: HexType, dtype: float64
# after: 1192    8.0
# Name: HexType, dtype: float64
# before:  6140    0.0
# Name: HexType, dtype: float64
# after: 6140    8.0
# Name: HexType, dtype: float64
# before:  7401    0.0
# Name: HexType, dtype: float64
# after: 7401    8.0
# Name: HexType, dtype: float64
# before:  7610    0.0
# Name: HexType, dtype: float64
# after: 7610    8.0
# Name: HexType, dtype: float64
# before:  9191    0.0
# Name: HexType, dtype: float64
# after: 9191    8.0
# Name: HexType, dtype: float64
# before:  9128    0.0
# Name: HexType, dtype: float64
# after: 9128    8.0
# Name: HexType, dtype: float64
# before:  2567    0.0
# Name: HexType, dtype: float64
# after: 2567    8.0
# Name: HexType, dtype: float64
# before:  6623    0.0
# Name: HexType, dtype: float64
# after: 6623    8.0
# Name: HexType, dtype: float64
# before:  9644    0.0
# Name: HexType, dtype: float64
# after: 9644    8.0
# Name: HexType, dtype: float64
# before:  5385    0.0
# Name: HexType, dtype: float64
# after: 5385    8.0
# Name: HexType, dtype: float64
# before:  285    0.0
# Name: HexType, dtype: float64
# after: 285    6.0
# Name: HexType, dtype: float64
# before:  6432    0.0
# Name: HexType, dtype: float64
# after: 6432    8.0
# Name: HexType, dtype: float64
# before:  5299    0.0
# Name: HexType, dtype: float64
# after: 5299    8.0
# Name: HexType, dtype: float64
# before:  2841    0.0
# Name: HexType, dtype: float64
# after: 2841    8.0
# Name: HexType, dtype: float64
# before:  7688    0.0
# Name: HexType, dtype: float64
# after: 7688    8.0
# Name: HexType, dtype: float64
# before:  9116    0.0
# Name: HexType, dtype: float64
# after: 9116    8.0
# Name: HexType, dtype: float64
# before:  1747    0.0
# Name: HexType, dtype: float64
# after: 1747    6.0
# Name: HexType, dtype: float64
# before:  7888    0.0
# Name: HexType, dtype: float64
# after: 7888    8.0
# Name: HexType, dtype: float64
# before:  8362    0.0
# Name: HexType, dtype: float64
# after: 8362    8.0
# Name: HexType, dtype: float64
# before:  801    0.0
# Name: HexType, dtype: float64
# after: 801    6.0
# Name: HexType, dtype: float64
# before:  5388    0.0
# Name: HexType, dtype: float64
# after: 5388    8.0
# Name: HexType, dtype: float64
# before:  2215    0.0
# Name: HexType, dtype: float64
# after: 2215    8.0
# Name: HexType, dtype: float64
# before:  9731    0.0
# Name: HexType, dtype: float64
# after: 9731    8.0
# Name: HexType, dtype: float64
# before:  2734    0.0
# Name: HexType, dtype: float64
# after: 2734    8.0
# Name: HexType, dtype: float64
# before:  8201    0.0
# Name: HexType, dtype: float64
# after: 8201    8.0
# Name: HexType, dtype: float64
# before:  8147    0.0
# Name: HexType, dtype: float64
# after: 8147    8.0
# Name: HexType, dtype: float64
# before:  1580    0.0
# Name: HexType, dtype: float64
# after: 1580    4.0
# Name: HexType, dtype: float64
# before:  3891    0.0
# Name: HexType, dtype: float64
# after: 3891    8.0
# Name: HexType, dtype: float64
# before:  3372    0.0
# Name: HexType, dtype: float64
# after: 3372    8.0
# Name: HexType, dtype: float64
# before:  5904    0.0
# Name: HexType, dtype: float64
# after: 5904    8.0
# Name: HexType, dtype: float64
# before:  3509    0.0
# Name: HexType, dtype: float64
# after: 3509    8.0
# Name: HexType, dtype: float64
# before:  4637    0.0
# Name: HexType, dtype: float64
# after: 4637    8.0
# Name: HexType, dtype: float64
# before:  7619    0.0
# Name: HexType, dtype: float64
# after: 7619    8.0
# Name: HexType, dtype: float64
# before:  3378    0.0
# Name: HexType, dtype: float64
# after: 3378    7.0
# Name: HexType, dtype: float64
# before:  1052    0.0
# Name: HexType, dtype: float64
# after: 1052    7.0
# Name: HexType, dtype: float64
# before:  5096    0.0
# Name: HexType, dtype: float64
# after: 5096    8.0
# Name: HexType, dtype: float64
# before:  3802    0.0
# Name: HexType, dtype: float64
# after: 3802    8.0
# Name: HexType, dtype: float64
# before:  8651    0.0
# Name: HexType, dtype: float64
# after: 8651    8.0
# Name: HexType, dtype: float64
# before:  5376    0.0
# Name: HexType, dtype: float64
# after: 5376    8.0
# Name: HexType, dtype: float64
# before:  1505    0.0
# Name: HexType, dtype: float64
# after: 1505    2.0
# Name: HexType, dtype: float64
# before:  5681    0.0
# Name: HexType, dtype: float64
# after: 5681    8.0
# Name: HexType, dtype: float64
# before:  2319    0.0
# Name: HexType, dtype: float64
# after: 2319    8.0
# Name: HexType, dtype: float64
# before:  2764    0.0
# Name: HexType, dtype: float64
# after: 2764    8.0
# Name: HexType, dtype: float64
# before:  1815    0.0
# Name: HexType, dtype: float64
# after: 1815    8.0
# Name: HexType, dtype: float64
# before:  7224    0.0
# Name: HexType, dtype: float64
# after: 7224    5.0
# Name: HexType, dtype: float64
# before:  2006    0.0
# Name: HexType, dtype: float64
# after: 2006    5.0
# Name: HexType, dtype: float64
# before:  5648    0.0
# Name: HexType, dtype: float64
# after: 5648    8.0
# Name: HexType, dtype: float64
# before:  8347    0.0
# Name: HexType, dtype: float64
# after: 8347    8.0
# Name: HexType, dtype: float64
# before:  449    0.0
# Name: HexType, dtype: float64
# after: 449    5.0
# Name: HexType, dtype: float64
# before:  193    0.0
# Name: HexType, dtype: float64
# after: 193    6.0
# Name: HexType, dtype: float64
# before:  8075    0.0
# Name: HexType, dtype: float64
# after: 8075    5.0
# Name: HexType, dtype: float64
# before:  4899    0.0
# Name: HexType, dtype: float64
# after: 4899    8.0
# Name: HexType, dtype: float64
# before:  2349    0.0
# Name: HexType, dtype: float64
# after: 2349    5.0
# Name: HexType, dtype: float64
# before:  3754    0.0
# Name: HexType, dtype: float64
# after: 3754    8.0
# Name: HexType, dtype: float64
# before:  5111    0.0
# Name: HexType, dtype: float64
# after: 5111    8.0
# Name: HexType, dtype: float64
# before:  6614    0.0
# Name: HexType, dtype: float64
# after: 6614    7.0
# Name: HexType, dtype: float64
# before:  3068    0.0
# Name: HexType, dtype: float64
# after: 3068    8.0
# Name: HexType, dtype: float64
# before:  2227    0.0
# Name: HexType, dtype: float64
# after: 2227    8.0
# Name: HexType, dtype: float64
# before:  5582    0.0
# Name: HexType, dtype: float64
# after: 5582    8.0
# Name: HexType, dtype: float64
# before:  6635    0.0
# Name: HexType, dtype: float64
# after: 6635    8.0
# Name: HexType, dtype: float64
# before:  4115    0.0
# Name: HexType, dtype: float64
# after: 4115    8.0
# Name: HexType, dtype: float64
# before:  1774    0.0
# Name: HexType, dtype: float64
# after: 1774    4.0
# Name: HexType, dtype: float64
# before:  3998    0.0
# Name: HexType, dtype: float64
# after: 3998    8.0
# Name: HexType, dtype: float64
# before:  5066    0.0
# Name: HexType, dtype: float64
# after: 5066    8.0
# Name: HexType, dtype: float64
# before:  9919    0.0
# Name: HexType, dtype: float64
# after: 9919    5.0
# Name: HexType, dtype: float64
# before:  2343    0.0
# Name: HexType, dtype: float64
# after: 2343    7.0
# Name: HexType, dtype: float64
# before:  7118    0.0
# Name: HexType, dtype: float64
# after: 7118    7.0
# Name: HexType, dtype: float64
# before:  4670    0.0
# Name: HexType, dtype: float64
# after: 4670    8.0
# Name: HexType, dtype: float64
# before:  5824    0.0
# Name: HexType, dtype: float64
# after: 5824    8.0
# Name: HexType, dtype: float64
# before:  3107    0.0
# Name: HexType, dtype: float64
# after: 3107    8.0
# Name: HexType, dtype: float64
# before:  5585    0.0
# Name: HexType, dtype: float64
# after: 5585    8.0
# Name: HexType, dtype: float64
# before:  5308    0.0
# Name: HexType, dtype: float64
# after: 5308    8.0
# Name: HexType, dtype: float64
# before:  4407    0.0
# Name: HexType, dtype: float64
# after: 4407    8.0
# Name: HexType, dtype: float64
# before:  3494    0.0
# Name: HexType, dtype: float64
# after: 3494    8.0
# Name: HexType, dtype: float64
# before:  6328    0.0
# Name: HexType, dtype: float64
# after: 6328    8.0
# Name: HexType, dtype: float64
# before:  1085    0.0
# Name: HexType, dtype: float64
# after: 1085    1.0
# Name: HexType, dtype: float64
# before:  3140    0.0
# Name: HexType, dtype: float64
# after: 3140    7.0
# Name: HexType, dtype: float64
# before:  1201    0.0
# Name: HexType, dtype: float64
# after: 1201    8.0
# Name: HexType, dtype: float64
# before:  42    0.0
# Name: HexType, dtype: float64
# after: 42    8.0
# Name: HexType, dtype: float64
# before:  2367    0.0
# Name: HexType, dtype: float64
# after: 2367    6.0
# Name: HexType, dtype: float64
# before:  1222    0.0
# Name: HexType, dtype: float64
# after: 1222    7.0
# Name: HexType, dtype: float64
# before:  548    0.0
# Name: HexType, dtype: float64
# after: 548    7.0
# Name: HexType, dtype: float64
# before:  4267    0.0
# Name: HexType, dtype: float64
# after: 4267    8.0
# Name: HexType, dtype: float64
# before:  2009    0.0
# Name: HexType, dtype: float64
# after: 2009    5.0
# Name: HexType, dtype: float64
# before:  9209    0.0
# Name: HexType, dtype: float64
# after: 9209    8.0
# Name: HexType, dtype: float64
# before:  3751    0.0
# Name: HexType, dtype: float64
# after: 3751    8.0
# Name: HexType, dtype: float64
# before:  5806    0.0
# Name: HexType, dtype: float64
# after: 5806    8.0
# Name: HexType, dtype: float64
# before:  1034    0.0
# Name: HexType, dtype: float64
# after: 1034    8.0
# Name: HexType, dtype: float64
# before:  3593    0.0
# ...
# Name: HexType, dtype: float64
# before:  9167    0.0
# Name: HexType, dtype: float64
# after: 9167    8.0
# Name: HexType, dtype: float64
# before:  7342    0.0
# Name: HexType, dtype: float64
# after: 7342    8.0
# Name: HexType, dtype: float64
# before:  12    0.0
# Name: HexType, dtype: float64
# after: 12    8.0
# Name: HexType, dtype: float64
# before:  5108    0.0
# Name: HexType, dtype: float64
# after: 5108    8.0
# Name: HexType, dtype: float64
# before:  3900    0.0
# Name: HexType, dtype: float64
# after: 3900    8.0
# Name: HexType, dtype: float64
# before:  3524    0.0
# Name: HexType, dtype: float64
# after: 3524    8.0
# Name: HexType, dtype: float64
# before:  9173    0.0
# Name: HexType, dtype: float64
# after: 9173    8.0
# Name: HexType, dtype: float64
# before:  2731    0.0
# Name: HexType, dtype: float64
# after: 2731    8.0
# Name: HexType, dtype: float64
# before:  2856    0.0
# Name: HexType, dtype: float64
# after: 2856    7.0
# Name: HexType, dtype: float64
# before:  8410    0.0
# Name: HexType, dtype: float64
# after: 8410    8.0
# Name: HexType, dtype: float64
# before:  1845    0.0
# Name: HexType, dtype: float64
# after: 1845    4.0
# Name: HexType, dtype: float64
# before:  694    0.0
# Name: HexType, dtype: float64
# after: 694    8.0
# Name: HexType, dtype: float64
# before:  8174    0.0
# Name: HexType, dtype: float64
# after: 8174    8.0
# Name: HexType, dtype: float64
# before:  5892    0.0
# Name: HexType, dtype: float64
# after: 5892    8.0
# Name: HexType, dtype: float64
# before:  1711    0.0
# Name: HexType, dtype: float64
# after: 1711    8.0
# Name: HexType, dtype: float64
# before:  5391    0.0
# Name: HexType, dtype: float64
# after: 5391    8.0
# Name: HexType, dtype: float64
# before:  4291    0.0
# Name: HexType, dtype: float64
# after: 4291    8.0
# Name: HexType, dtype: float64
# before:  8845    0.0
# Name: HexType, dtype: float64
# after: 8845    8.0
# Name: HexType, dtype: float64
# before:  8860    0.0
# Name: HexType, dtype: float64
# after: 8860    8.0
# Name: HexType, dtype: float64
# before:  3894    0.0
# Name: HexType, dtype: float64
# after: 3894    8.0
# Name: HexType, dtype: float64
# before:  6310    0.0
# Name: HexType, dtype: float64
# after: 6310    8.0
# Name: HexType, dtype: float64
# before:  697    0.0
# Name: HexType, dtype: float64
# after: 697    7.0
# Name: HexType, dtype: float64
# before:  232    0.0
# Name: HexType, dtype: float64
# after: 232    2.0
# Name: HexType, dtype: float64
# before:  2823    0.0
# Name: HexType, dtype: float64
# after: 2823    8.0
# Name: HexType, dtype: float64
# before:  4851    0.0
# Name: HexType, dtype: float64
# after: 4851    8.0
# Name: HexType, dtype: float64
# before:  5928    0.0
# Name: HexType, dtype: float64
# after: 5928    7.0
# Name: HexType, dtype: float64
# before:  7112    0.0
# Name: HexType, dtype: float64
# after: 7112    8.0
# Name: HexType, dtype: float64
# before:  7130    0.0
# Name: HexType, dtype: float64
# after: 7130    8.0
# Name: HexType, dtype: float64
# before:  2051    0.0
# Name: HexType, dtype: float64
# after: 2051    8.0
# Name: HexType, dtype: float64
# before:  4780    0.0
# Name: HexType, dtype: float64
# after: 4780    8.0
# Name: HexType, dtype: float64
# before:  6677    0.0
# Name: HexType, dtype: float64
# after: 6677    8.0
# Name: HexType, dtype: float64
# before:  196    0.0
# Name: HexType, dtype: float64
# after: 196    5.0
# Name: HexType, dtype: float64
# before:  6966    0.0
# Name: HexType, dtype: float64
# after: 6966    8.0
# Name: HexType, dtype: float64
# before:  273    0.0
# Name: HexType, dtype: float64
# after: 273    7.0
# Name: HexType, dtype: float64
# before:  2630    0.0
# Name: HexType, dtype: float64
# after: 2630    8.0
# Name: HexType, dtype: float64
# before:  7076    0.0
# Name: HexType, dtype: float64
# after: 7076    8.0
# Name: HexType, dtype: float64
# before:  7428    0.0
# Name: HexType, dtype: float64
# after: 7428    8.0
# Name: HexType, dtype: float64
# before:  6572    0.0
# Name: HexType, dtype: float64
# after: 6572    8.0
# Name: HexType, dtype: float64
# before:  6808    0.0
# Name: HexType, dtype: float64
# after: 6808    8.0
# Name: HexType, dtype: float64
# before:  8469    0.0
# Name: HexType, dtype: float64
# after: 8469    8.0
# Name: HexType, dtype: float64
# before:  2465    0.0
# Name: HexType, dtype: float64
# after: 2465    5.0
# Name: HexType, dtype: float64
# before:  2847    0.0
# Name: HexType, dtype: float64
# after: 2847    7.0
# Name: HexType, dtype: float64
# before:  6596    0.0
# Name: HexType, dtype: float64
# after: 6596    8.0
# Name: HexType, dtype: float64
# before:  8657    0.0
# Name: HexType, dtype: float64
# after: 8657    8.0
# Name: HexType, dtype: float64
# before:  3817    0.0
# Name: HexType, dtype: float64
# after: 3817    8.0
# Name: HexType, dtype: float64
# before:  6059    0.0
# Name: HexType, dtype: float64
# after: 6059    8.0
# Name: HexType, dtype: float64
# before:  10008    0.0
# Name: HexType, dtype: float64
# after: 10008    3.0
# Name: HexType, dtype: float64
# before:  9743    0.0
# Name: HexType, dtype: float64
# after: 9743    8.0
# Name: HexType, dtype: float64
# before:  2030    0.0
# Name: HexType, dtype: float64
# after: 2030    6.0
# Name: HexType, dtype: float64
# before:  247    0.0
# Name: HexType, dtype: float64
# after: 247    6.0
# Name: HexType, dtype: float64
# before:  4625    0.0
# Name: HexType, dtype: float64
# after: 4625    8.0
# Name: HexType, dtype: float64
# before:  4160    0.0
# Name: HexType, dtype: float64
# after: 4160    8.0
# Name: HexType, dtype: float64
# before:  3011    0.0
# Name: HexType, dtype: float64
# after: 3011    8.0
# Name: HexType, dtype: float64
# before:  5552    0.0
# Name: HexType, dtype: float64
# after: 5552    8.0
# Name: HexType, dtype: float64
# before:  7938    0.0
# Name: HexType, dtype: float64
# after: 7938    8.0
# Name: HexType, dtype: float64
# before:  2874    0.0
# Name: HexType, dtype: float64
# after: 2874    6.0
# Name: HexType, dtype: float64
# before:  5030    0.0
# Name: HexType, dtype: float64
# after: 5030    8.0
# Name: HexType, dtype: float64
# before:  2603    0.0
# Name: HexType, dtype: float64
# after: 2603    6.0
# Name: HexType, dtype: float64
# before:  5102    0.0
# Name: HexType, dtype: float64
# after: 5102    8.0
# Name: HexType, dtype: float64
# before:  6095    0.0
# Name: HexType, dtype: float64
# after: 6095    7.0
# Name: HexType, dtype: float64
# before:  4055    0.0
# Name: HexType, dtype: float64
# after: 4055    8.0
# Name: HexType, dtype: float64
# before:  9683    0.0
# Name: HexType, dtype: float64
# after: 9683    8.0
# Name: HexType, dtype: float64
# before:  8869    0.0
# Name: HexType, dtype: float64
# after: 8869    8.0
# Name: HexType, dtype: float64
# before:  4344    0.0
# Name: HexType, dtype: float64
# after: 4344    8.0
# Name: HexType, dtype: float64
# before:  4768    0.0
# Name: HexType, dtype: float64
# after: 4768    8.0
# Name: HexType, dtype: float64
# before:  9674    0.0
# Name: HexType, dtype: float64
# after: 9674    8.0
# Name: HexType, dtype: float64
# before:  6957    0.0
# Name: HexType, dtype: float64
# after: 6957    8.0
# Name: HexType, dtype: float64
# before:  5039    0.0
# Name: HexType, dtype: float64
# after: 5039    8.0
# Name: HexType, dtype: float64
# before:  9728    0.0
# Name: HexType, dtype: float64
# after: 9728    8.0
# Name: HexType, dtype: float64
# before:  9665    0.0
# Name: HexType, dtype: float64
# after: 9665    8.0
# Name: HexType, dtype: float64
# before:  5114    0.0
# Name: HexType, dtype: float64
# after: 5114    8.0
# Name: HexType, dtype: float64
# before:  4264    0.0
# Name: HexType, dtype: float64
# after: 4264    8.0
# Name: HexType, dtype: float64
# before:  8997    0.0
# Name: HexType, dtype: float64
# after: 8997    8.0
# Name: HexType, dtype: float64
# before:  2281    0.0
# Name: HexType, dtype: float64
# after: 2281    6.0
# Name: HexType, dtype: float64
# before:  4279    0.0
# Name: HexType, dtype: float64
# after: 4279    8.0
# Name: HexType, dtype: float64
# before:  8708    0.0
# Name: HexType, dtype: float64
# after: 8708    8.0
# Name: HexType, dtype: float64
# before:  5284    0.0
# Name: HexType, dtype: float64
# after: 5284    8.0
# Name: HexType, dtype: float64
# before:  6689    0.0
# Name: HexType, dtype: float64
# after: 6689    8.0
# Name: HexType, dtype: float64
# before:  1544    0.0
# Name: HexType, dtype: float64
# after: 1544    8.0
# Name: HexType, dtype: float64
# before:  1502    0.0
# Name: HexType, dtype: float64
# after: 1502    2.0
# Name: HexType, dtype: float64
# before:  6638    0.0
# Name: HexType, dtype: float64
# after: 6638    8.0
# Name: HexType, dtype: float64
# before:  7166    0.0
# Name: HexType, dtype: float64
# after: 7166    8.0
# Name: HexType, dtype: float64
# before:  5940    0.0
# Name: HexType, dtype: float64
# after: 5940    8.0
# Name: HexType, dtype: float64
# before:  51    0.0
# Name: HexType, dtype: float64
# after: 51    7.0
# Name: HexType, dtype: float64
# before:  7410    0.0
# Name: HexType, dtype: float64
# after: 7410    8.0
# Name: HexType, dtype: float64
# before:  7384    0.0
# Name: HexType, dtype: float64
# after: 7384    8.0
# Name: HexType, dtype: float64
# before:  4616    0.0
# Name: HexType, dtype: float64
# after: 4616    8.0
# Name: HexType, dtype: float64
# before:  425    0.0
# Name: HexType, dtype: float64
# after: 425    5.0
# Name: HexType, dtype: float64
# before:  6343    0.0
# Name: HexType, dtype: float64
# after: 6343    8.0
# Name: HexType, dtype: float64
# before:  1274    0.0
# Name: HexType, dtype: float64
# after: 1274    5.0
# Name: HexType, dtype: float64
# before:  4010    0.0
# Name: HexType, dtype: float64
# after: 4010    8.0
# Name: HexType, dtype: float64
# before:  4294    0.0
# Name: HexType, dtype: float64
# after: 4294    8.0
# Name: HexType, dtype: float64
# before:  309    0.0
# Name: HexType, dtype: float64
# after: 309    6.0
# Name: HexType, dtype: float64
# before:  3578    0.0
# Name: HexType, dtype: float64
# after: 3578    8.0
# Name: HexType, dtype: float64
# before:  9364    0.0
# Name: HexType, dtype: float64
# after: 9364    8.0
# Name: HexType, dtype: float64
# before:  9623    0.0
# Name: HexType, dtype: float64
# after: 9623    8.0
# Name: HexType, dtype: float64
# before:  45    0.0
# Name: HexType, dtype: float64
# after: 45    6.0
# Name: HexType, dtype: float64
# before:  3491    0.0
# Name: HexType, dtype: float64
# after: 3491    8.0
# Name: HexType, dtype: float64
# before:  5851    0.0
# Name: HexType, dtype: float64
# after: 5851    8.0
# Name: HexType, dtype: float64
# before:  1785    0.0
# Name: HexType, dtype: float64
# after: 1785    5.0
# Name: HexType, dtype: float64
# before:  4601    0.0
# Name: HexType, dtype: float64
# after: 4601    8.0
# Name: HexType, dtype: float64
# before:  4673    0.0
# Name: HexType, dtype: float64
# after: 4673    6.0
# Name: HexType, dtype: float64
# before:  8231    0.0
# Name: HexType, dtype: float64
# after: 8231    8.0
# Name: HexType, dtype: float64
# before:  5329    0.0
# Name: HexType, dtype: float64
# after: 5329    8.0
# Name: HexType, dtype: float64
# before:  1493    0.0
# Name: HexType, dtype: float64
# after: 1493    5.0
# Name: HexType, dtype: float64
# before:  5543    0.0
# Name: HexType, dtype: float64
# after: 5543    8.0
# Name: HexType, dtype: float64
# before:  764    0.0
# Name: HexType, dtype: float64
# after: 764    5.0
# Name: HexType, dtype: float64
# before:  4565    0.0
# Name: HexType, dtype: float64
# after: 4565    8.0
# Name: HexType, dtype: float64
# before:  4831    0.0
# Name: HexType, dtype: float64
# after: 4831    8.0
# Name: HexType, dtype: float64
# before:  9000    0.0
# Name: HexType, dtype: float64
# after: 9000    8.0
# Name: HexType, dtype: float64
# before:  7947    0.0
# Name: HexType, dtype: float64
# after: 7947    8.0
# Name: HexType, dtype: float64
# before:  6396    0.0
# Name: HexType, dtype: float64
# after: 6396    8.0
# Name: HexType, dtype: float64
# before:  9680    0.0
# Name: HexType, dtype: float64
# after: 9680    8.0
# Name: HexType, dtype: float64
# before:  238    0.0
# Name: HexType, dtype: float64
# after: 238    3.0
# Name: HexType, dtype: float64
# before:  9620    0.0
# Name: HexType, dtype: float64
# after: 9620    8.0
# Name: HexType, dtype: float64
# before:  6814    0.0
# Name: HexType, dtype: float64
# after: 6814    8.0
# Name: HexType, dtype: float64
# before:  27    0.0
# Name: HexType, dtype: float64
# after: 27    6.0
# Name: HexType, dtype: float64
# before:  3757    0.0
# Name: HexType, dtype: float64
# after: 3757    8.0
# Name: HexType, dtype: float64
# before:  5630    0.0
# Name: HexType, dtype: float64
# after: 5630    8.0
# Name: HexType, dtype: float64
# before:  5525    0.0
# Name: HexType, dtype: float64
# after: 5525    5.0
# Name: HexType, dtype: float64
# before:  3050    0.0
# Name: HexType, dtype: float64
# after: 3050    6.0
# Name: HexType, dtype: float64
# before:  2018    0.0
# Name: HexType, dtype: float64
# after: 2018    4.0
# Name: HexType, dtype: float64
# before:  2337    0.0
# Name: HexType, dtype: float64
# after: 2337    8.0
# Name: HexType, dtype: float64
# before:  8374    0.0
# Name: HexType, dtype: float64
# after: 8374    8.0
# Name: HexType, dtype: float64
# before:  1466    0.0
# Name: HexType, dtype: float64
# after: 1466    8.0
# Name: HexType, dtype: float64
# before:  4845    0.0
# Name: HexType, dtype: float64
# after: 4845    5.0
# Name: HexType, dtype: float64
# before:  6894    0.0
# Name: HexType, dtype: float64
# after: 6894    8.0
# Name: HexType, dtype: float64
# before:  4914    0.0
# Name: HexType, dtype: float64
# after: 4914    8.0
# Name: HexType, dtype: float64
# before:  9230    0.0
# Name: HexType, dtype: float64
# after: 9230    8.0
# Name: HexType, dtype: float64
# before:  1800    0.0
# Name: HexType, dtype: float64
# after: 1800    8.0
# Name: HexType, dtype: float64
# before:  7404    0.0
# Name: HexType, dtype: float64
# after: 7404    8.0
# Name: HexType, dtype: float64
# before:  2588    0.0
# Name: HexType, dtype: float64
# after: 2588    8.0
# Name: HexType, dtype: float64
# before:  1293    0.0
# Name: HexType, dtype: float64
# after: 1293    8.0
# Name: HexType, dtype: float64
# before:  5812    0.0
# Name: HexType, dtype: float64
# after: 5812    8.0
# Name: HexType, dtype: float64
# before:  4844    0.0
# Name: HexType, dtype: float64
# after: 4844    5.0
# Name: HexType, dtype: float64
# before:  3506    0.0
# Name: HexType, dtype: float64
# after: 3506    8.0
# Name: HexType, dtype: float64
# before:  282    0.0
# Name: HexType, dtype: float64
# after: 282    5.0
# Name: HexType, dtype: float64
# before:  3089    0.0
# Name: HexType, dtype: float64
# after: 3089    8.0
# Name: HexType, dtype: float64
# before:  5860    0.0
# Name: HexType, dtype: float64
# after: 5860    8.0
# Name: HexType, dtype: float64
# before:  6179    0.0
# Name: HexType, dtype: float64
# after: 6179    8.0
# Name: HexType, dtype: float64
# before:  8955    0.0
# Name: HexType, dtype: float64
# after: 8955    8.0
# Name: HexType, dtype: float64
# before:  5367    0.0
# Name: HexType, dtype: float64
# after: 5367    8.0
# Name: HexType, dtype: float64
# before:  4309    0.0
# Name: HexType, dtype: float64
# after: 4309    8.0
# Name: HexType, dtype: float64
# before:  9385    0.0
# Name: HexType, dtype: float64
# after: 9385    8.0
# Name: HexType, dtype: float64
# before:  7067    0.0
# Name: HexType, dtype: float64
# after: 7067    8.0
# Name: HexType, dtype: float64
# before:  9904    0.0
# Name: HexType, dtype: float64
# after: 9904    5.0
# Name: HexType, dtype: float64
# before:  4034    0.0
# Name: HexType, dtype: float64
# after: 4034    8.0
# Name: HexType, dtype: float64
# before:  3020    0.0
# Name: HexType, dtype: float64
# after: 3020    8.0
# Name: HexType, dtype: float64
# before:  7646    0.0
# Name: HexType, dtype: float64
# after: 7646    8.0
# Name: HexType, dtype: float64
# before:  1234    0.0
# Name: HexType, dtype: float64
# after: 1234    7.0
# Name: HexType, dtype: float64
# before:  4088    0.0
# Name: HexType, dtype: float64
# after: 4088    8.0
# Name: HexType, dtype: float64
# before:  4064    0.0
# Name: HexType, dtype: float64
# after: 4064    8.0
# Name: HexType, dtype: float64
# before:  4863    0.0
# Name: HexType, dtype: float64
# after: 4863    8.0
# Name: HexType, dtype: float64
# before:  6340    0.0
# Name: HexType, dtype: float64
# after: 6340    8.0
# Name: HexType, dtype: float64
# before:  7318    0.0
# Name: HexType, dtype: float64
# after: 7318    8.0
# Name: HexType, dtype: float64
# before:  4547    0.0
# Name: HexType, dtype: float64
# after: 4547    8.0
# Name: HexType, dtype: float64
# before:  6835    0.0
# Name: HexType, dtype: float64
# after: 6835    8.0
# Name: HexType, dtype: float64
# before:  254    0.0
# Name: HexType, dtype: float64
# after: 254    5.0
# Name: HexType, dtype: float64
# before:  4556    0.0
# Name: HexType, dtype: float64
# after: 4556    8.0
# Name: HexType, dtype: float64
# before:  715    0.0
# Name: HexType, dtype: float64
# after: 715    7.0
# Name: HexType, dtype: float64

# %%
hexgrid10km.loc[hexgrid10km['IDX'] == '2.81','HexType']
# Out:
# 172    8.0
# Name: HexType, dtype: float64

# %%
hexgrid10km = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10kmHungarybreadRevised.shp')

# %%
hexgrid10km.to_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10kmHungarybreadRevised.shp')

# %%
# You cannot find a Cell according to HexType because it is float due to imprecise compaqrisons. You have to round the float to an int with astype(int) 
hexgrid10km.loc[hexgrid10km['HexType'].astype(int) == 7, ['HexType','Bread','IDX']]
# Out:
#       HexType  Bread    IDX
# 17        7.0      0   0.67
# 28        7.0      0   0.56
# 32        7.0      2   0.52
# 35        7.0      2   0.49
# 37        7.0      0   0.47
# ...       ...    ...    ...
# 7725      7.0      0   90.8
# 7794      7.0      2  91.24
# 7808      7.0      0  91.10
# 7889      7.0      0  92.14
# 8271      7.0      0  97.57
#
# [527 rows x 3 columns]

# %%
bread['settl'][hexgrid10km.loc[20,'HexType'].astype(int).astype(str)]
# Out:
# 0

# %%
# reload to reset
# hexgrid10km = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10kmHungary Copy3.shp')
# hexgrid10km.drop(range(10200,10219), inplace=True)
# settls = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/CityHungaryEPSG3857.shp')

# %% [markdown]
# # Now the calls to the functions

# %%
# hexgrid10km[hexgrid10km.index.duplicated()]
# https://saturncloud.io/blog/how-to-drop-duplicated-index-in-a-pandas-dataframe-a-complete-guide/

# %%
OSM_Cities_Hun  = calc_previous_population(1200) # year of campaign time
###
filt2 = hexgrid30km['settl'].notnull() 
for hex in hexgrid30km.loc[filt2,'COORDIDX']: # go through all hexes with settlements
    # print('hex', hex, 'type:', type(hex))
    hexgrid30km['update'] = [0] * hexgrid30km.shape[0] # set to zero
    hexgrid30km.loc[hex,'update'] = round(hexgrid30km.loc[hex,'OriginalInfra']) 
    hexgrid30km = propagate(hex,hexgrid30km) # propagate infrastructure to neighbours
    #breakpoint()abs
    pass

###


hexgrid30km = small_hexes_in_big_hexes(hexgrid30km) # attach 10km hexes to 30km hexes
###
# iterate over collumn hex type and fill with a randowm hex group according to infrastructure.
for key17 in hexgrid30km.index:
    infra = hexgrid30km.loc[key17,'Infra']
    if infra > 448:
        infra = 448
    infra = str(int(infra)) 
    hexgrid30km.at[key17,'Hex_Type'] = getHexGroup(allInfras,infra)

###
hexgrid10km = write_HexType_to_10km(hexgrid30km, hexgrid10km)
###
hexgrid10km = edge_hex_type(hexgrid30km,hexgrid10km)
###
# hexgrid10km.to_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10kmHungary Copy4.shp')
###
hexgrid10km = gpd.sjoin(hexgrid10km, settls, how ="left", predicate='contains') # What if there are multiple Selltlements in one hex?
hexgrid10km.rename(columns={'index_right':'IDsettl'}, inplace=True)
hexgrid10km = gpd.sjoin(hexgrid10km,miningfeature,how='left',predicate='contains')
# this creates new rows if there are multiple matches. See https://stackoverflow.com/questions/916414/how-can-a-left-outer-join-return-more-records-than-exist-in-the-left-table
hexgrid10km.rename(columns={'index_right':'IDminingfeature'}, inplace=True)
hexgrid10km.drop_duplicates(subset='geometry', keep='first', inplace=True) # this is what i want.
hexgrid10km = gpd.sjoin(hexgrid10km,contemp_mines,how='left',predicate='contains')
hexgrid10km.rename(columns={'index_right':'IDcontemp_mines'}, inplace=True) # rename to avoid duplicate column names
hexgrid10km.drop_duplicates(subset='geometry', keep='first', inplace=True) # this is what i want.
hexgrid10km = gpd.sjoin(hexgrid10km,hist_mines,how='left',predicate='contains') # left join because not all hexes have a historical mine
hexgrid10km.rename(columns={'index_right':'IDhist_mines'}, inplace=True) # rename to avoid duplicate column names
#hexgrid10km.set_index('IDX', inplace=True) #drop=False means that the COORDIDX collumn is not deleted
hexgrid10km.drop_duplicates(subset='geometry', keep='first', inplace=True) # this is what i want.
hexgrid10km = hexgrid10km.loc[~hexgrid10km.index.duplicated(keep='first')] # eliminates lines with duplicate index
###
hexgrid10km = set_bread(hexgrid10km)
###
hexgrid10km.to_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10kmHungary Copy with Bread.shp')
###
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 OSM_Cities_Hun  = calc_previous_population(1200) # year of campaign time
#       2 ###
#       3 filt2 = hexgrid30km['settl'].notnull()
#
# Cell In[88], line 44, in calc_previous_population(campaigntime)
#      42 #print('Wikidata Item: ' , q)
#      43 requeststring = 'https://m.wikidata.org/wiki/Special:EntityData/'+ str(q) + '.json'
# ---> 44 x = requests.get(requeststring)
#      45 y = json.loads(x.content) #convert json to python object
#      46 try: # will fail if P571 == inception does not exist
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/requests/adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     484     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#     502     raise ConnectionError(err, request=request)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/urllib3/connectionpool.py:403, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     401 # Trigger any extra validation we need to do.
#     402 try:
# --> 403     self._validate_conn(conn)
#     404 except (SocketTimeout, BaseSSLError) as e:
#     405     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     406     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/urllib3/connectionpool.py:1053, in HTTPSConnectionPool._validate_conn(self, conn)
#    1051 # Force connect early to allow us to validate the connection.
#    1052 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1053     conn.connect()
#    1055 if not conn.is_verified:
#    1056     warnings.warn(
#    1057         (
#    1058             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1063         InsecureRequestWarning,
#    1064     )
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/urllib3/connection.py:363, in HTTPSConnection.connect(self)
#     361 def connect(self):
#     362     # Add certificate verification
# --> 363     self.sock = conn = self._new_conn()
#     364     hostname = self.host
#     365     tls_in_tls = False
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     171     extra_kw["socket_options"] = self.socket_options
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#     179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      83     if source_address:
#      84         sock.bind(source_address)
# ---> 85     sock.connect(sa)
#      86     return sock
#      88 except socket.error as e:
#
# KeyboardInterrupt:

# %% [markdown]
# # Random bits and ends:

# %%
mineraloccurrence=gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/Mining/m4eu20211209.gpkg', layer='commodity')

# %%
contemp_mines.head()

# %%
# hexgrid30km.to_file("/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/30KMHungaryClipCopy4.shp")

# %%
# hexgrid10km.to_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10kmHungary Copy4.shp')

# %%
# OSM_Cities_Hun.to_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/city saved/OSM_Cities_Hun_Points_With_POP.gpkg', driver='GPKG', layer='place_city')

# %%
hexgrid10km.head()

# %%
# %debug

# %%
hexgrid30km['update'].unique()

# %%
hexgrid30km.plot(column = 'Infra')

# %%
hexgrid30km.loc[filt2,'COORDIDX']

# %%
hexgrid30km.loc[hexgrid30km['COORDIDX'] == hex1_COORDS, 'Infra']

# %%
test = hexgrid30km['COORDIDX'] == hex1_COORDS

# %%
hexgrid30km.loc[hexgrid30km['COORDIDX'] == str(hex1_COORDS), 'Infra'].item()

# %%
#hexgrid30km['update']

# %%
test = gpd.sjoin(hexgrid30km, settls, how='left', op = 'contains')

# %%
def to_null(x):
    x = 0
    return x
hexgrid30km['Infra'] = hexgrid30km['Infra'].apply(to_null)

# %%
hexgrid30km.crs == settls.crs

# %%
#hexgrid30km.drop('COORDIDX', axis = 1, inplace = True)

# %%
hexgrid10km.plot(column = 'HeyType')

# %%
hexgrid30km.plot(column = 'Infra')

# %%
# import a netcdf4 file and convert it to a tiff

import xarray as xr

# Read the GRIB file using xarray
ds = xr.open_dataset('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/Hydrology/mars_data_0.nc' , engine='netcdf4').load()
xds = ds.rio.write_crs("epsg:4326", inplace=True) # redundant
xds['dis06'].rio.to_raster('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/Hydrology/mars_data_0.tif')

# %%
# first import the shapefiles of the rivers and the tiff of the hydrology
river_layer_name = fiona.listlayers('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/hn rivers.gpkg')
river_hn_lines = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/hn rivers.gpkg',layer = river_layer_name[0])
import rasterio
river_raster = rasterio.open('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/Hydrology/mars_data_0.tif')

# %% [markdown]
# # Find Flat areas Hexes for Cultivated. If done on a whole map it crashes the Kernel.

# %%
slope_raster = rasterio.open('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/slope_hungary.tif')

# %%
import rasterio.plot

# %%
# creates a generator object
shape = rasterio.features.shapes(slope_raster.read(1), mask=None, transform=slope_raster.transform)
# if you want to list all point in the generator object, if crashes the kernel. This is why ii is a generator object in the first place
pol = list(shape)

# %% [markdown]
# ## Masking a raster layer Tutorial
# file:///Users/aljoschabeyer/Downloads/Masking%20_%20clipping%20raster%20%E2%80%94%20Intro%20to%20Python%20GIS%20documentation.html

# %%
import rasterio
from rasterio.plot import show
from rasterio.plot import show_hist
from rasterio.mask import mask
from shapely.geometry import box
import geopandas as gpd
from fiona.crs import from_epsg
import pycrs # pip3 install pycrs

# %%
fp =r'/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/Hungary Clips/Merged/HungaryMerged.tif'
#fp = r'/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/slope_hungary.tif'
out_tif = r'/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/slope_hungary-MASK.tif'

# %%
data = rasterio.open(fp)

# %%
show(data, cmap='terrain') # cmap='terrain' is a color map, see https://matplotlib.org/stable/tutorials/colors/colormaps.html
# Out:
# <Axes: >

# %% [markdown]
# ### Create a bounding box

# %%
# create a bounding box with Shapely WGS84 coordinates
minx, miny = 24.60, 60.00
maxx, maxy = 25.22, 60.35
bbox = box(minx, miny, maxx, maxy)
# insert the bbox into a GeoDataFrame
geo = gpd.GeoDataFrame({'geometry': bbox}, index=[0], crs=from_epsg(4326))
Re-project into the same coordinate system as the raster data
geo = geo.to_crs(crs=data.crs.data)

# %% [markdown]
# ### Alternatively open a bounding box of 1 acre

# %%
shape_fp = r'/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/Knight Fee Manor.shp'
geo = gpd.read_file(shape_fp)

# %% [markdown]
# ### Open 10-mile-hex geometry as bounding box

# %%
hexgrid10kmPOLYGONS = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10kmHungarybreadRevised.shp')

# %% [markdown]
# ### Next we need to get the coordinates of the geometry in such a format that rasterio wants them. This can be conducted easily with following function

# %%
def getFeatures(gdf):
    """Function to parse features from GeoDataFrame in such a manner that rasterio wants them"""
    import json
    return [json.loads(gdf.to_json())['features'][0]['geometry']]

# %% [markdown]
# ### Get the geometry coordinates by using the function.

# %%
geo = hexgrid10kmPOLYGONS.loc[hexgrid10kmPOLYGONS['IDX'] == '2.81']
coords = getFeatures(geo)
print(coords)
# Out:
# [{'type': 'Polygon', 'coordinates': [[[1743340.1362820966, 5461158.247914326], [1746673.4711695977, 5466931.75329812], [1753340.1409445999, 5466931.75329812], [1756673.475832101, 5461158.247914326], [1753340.1409445999, 5455384.742530532], [1746673.4711695977, 5455384.742530532], [1743340.1362820966, 5461158.247914326]]]}]

# %% [markdown]
# ### Now we are ready to clip the raster with the polygon using the coords variable that we just created. Clipping the raster can be done easily with the mask function that we imported in the beginning from rasterio, and specifying clip=True.

# %%
out_img, out_transform = mask(data, shapes=coords, crop=True) # https://rasterio.readthedocs.io/en/stable/api/rasterio.mask.html

# %% [markdown]
# ### Next, we need to modify the metadata. Let’s start by copying the metadata from the original data file.

# %%
out_meta = data.meta.copy()
print(out_meta)
# Out:
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 47825, 'height': 29500, 'count': 1, 'crs': CRS.from_wkt('LOCAL_CS["WGS 84 / Pseudo-Mercator",UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]'), 'transform': Affine(30.922080776664007, 0.0, 1654324.613,
#        0.0, -45.22588836005499, 6592253.0628)}

# %% [markdown]
# ### Next we need to parse the EPSG value from the CRS so that we can create a Proj4 string using PyCRS library (to ensure that the projection information is saved correctly).

# %%
# Parse EPSG code
if data.crs.data:
    epsg_code = int(data.crs.data['init'][5:])
    print(epsg_code)
else:
    epsg_code = int(3857) # default to WGS84 Web Mercator (EPSG:3857)
    print('no code found, default to WGS84 Web Mercator (EPSG:3857)')
# Out:
# no code found, default to WGS84 Web Mercator (EPSG:3857)

# %% [markdown]
# ### Now we need to update the metadata with new dimensions, transform (affine) and CRS (as Proj4 text)

# %%
out_meta.update({"driver": "GTiff", "height": out_img.shape[1],"width": out_img.shape[2], "transform": out_transform, "crs": pycrs.parse.from_epsg_code(epsg_code).to_proj4()})

# %% [markdown]
# ### Finally, we can save the clipped raster to disk with following command.

# %%
with rasterio.open(out_tif, "w", **out_meta) as dest:
    dest.write(out_img)

# %%
clipped = rasterio.open(out_tif)
show(clipped, cmap='terrain')
# Out:
# <Axes: >

# %%
rasterio.plot.show(slope_raster)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[153], line 1
# ----> 1 rasterio.plot.show(slope_raster)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/rasterio/plot.py:166, in show(source, with_bounds, contour, contour_label_kws, ax, title, transform, adjust, **kwargs)
#     163     ax.set_title(title, fontweight='bold')
#     165 if show:
# --> 166     plt.show()
#     168 return ax
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/matplotlib/pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/IPython/core/formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/IPython/core/formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/matplotlib/backend_bases.py:2366, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2362 try:
#    2363     # _get_renderer may change the figure dpi (as vector formats
#    2364     # force the figure dpi to 72), so we need to set it again here.
#    2365     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366         result = print_method(
#    2367             filename,
#    2368             facecolor=facecolor,
#    2369             edgecolor=edgecolor,
#    2370             orientation=orientation,
#    2371             bbox_inches_restore=_bbox_inches_restore,
#    2372             **kwargs)
#    2373 finally:
#    2374     if bbox_inches and restore_bbox:
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/matplotlib/backend_bases.py:2232, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2228     optional_kws = {  # Passed by print_figure for other renderers.
#    2229         "dpi", "facecolor", "edgecolor", "orientation",
#    2230         "bbox_inches_restore"}
#    2231     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234 else:  # Let third-parties do as they see fit.
#    2235     print_method = meth
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:509, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     462 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     463     """
#     464     Write the figure to a PNG file.
#     465
#    (...)
#     507         *metadata*, including the default 'Software' key.
#     508     """
# --> 509     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:457, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     452 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     453     """
#     454     Draw the canvas, then save it using `.image.imsave` (to which
#     455     *pil_kwargs* and *metadata* are forwarded).
#     456     """
# --> 457     FigureCanvasAgg.draw(self)
#     458     mpl.image.imsave(
#     459         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:400, in FigureCanvasAgg.draw(self)
#     396 # Acquire a lock on the shared font cache.
#     397 with RendererAgg.lock, \
#     398      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     399       else nullcontext()):
# --> 400     self.figure.draw(self.renderer)
#     401     # A GUI class may be need to update a window using this draw, so
#     402     # don't forget to call the superclass.
#     403     super().draw()
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/matplotlib/figure.py:3175, in Figure.draw(self, renderer)
#    3172         # ValueError can occur when resizing a window.
#    3174 self.patch.draw(renderer)
# -> 3175 mimage._draw_list_compositing_images(
#    3176     renderer, self, artists, self.suppressComposite)
#    3178 for sfig in self.subfigs:
#    3179     sfig.draw(renderer)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/matplotlib/axes/_base.py:3064, in _AxesBase.draw(self, renderer)
#    3061 if artists_rasterized:
#    3062     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3064 mimage._draw_list_compositing_images(
#    3065     renderer, self, artists, self.figure.suppressComposite)
#    3067 renderer.close_group('axes')
#    3068 self.stale = False
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/matplotlib/image.py:641, in _ImageBase.draw(self, renderer, *args, **kwargs)
#     639         renderer.draw_image(gc, l, b, im, trans)
#     640 else:
# --> 641     im, l, b, trans = self.make_image(
#     642         renderer, renderer.get_image_magnification())
#     643     if im is not None:
#     644         renderer.draw_image(gc, l, b, im)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/matplotlib/image.py:949, in AxesImage.make_image(self, renderer, magnification, unsampled)
#     946 transformed_bbox = TransformedBbox(bbox, trans)
#     947 clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     948         else self.figure.bbox)
# --> 949 return self._make_image(self._A, bbox, transformed_bbox, clip,
#     950                         magnification, unsampled=unsampled)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/matplotlib/image.py:424, in _ImageBase._make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     416 if A.ndim == 2 and self._interpolation_stage != 'rgba':
#     417     # if we are a 2D array, then we are running through the
#     418     # norm + colormap transformation.  However, in general the
#    (...)
#     421
#     422     # TODO slice input array first
#     423     a_min = A.min()
# --> 424     a_max = A.max()
#     425     if a_min is np.ma.masked:  # All masked; values don't matter.
#     426         a_min, a_max = np.int32(0), np.int32(1)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/numpy/ma/core.py:5934, in MaskedArray.max(self, axis, out, fill_value, keepdims)
#    5932 # No explicit output
#    5933 if out is None:
# -> 5934     result = self.filled(fill_value).max(
#    5935         axis=axis, out=out, **kwargs).view(type(self))
#    5936     if result.ndim:
#    5937         # Set the mask
#    5938         result.__setmask__(newmask)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/numpy/ma/core.py:3851, in MaskedArray.filled(self, fill_value)
#    3849 result = self._data.copy('K')
#    3850 try:
# -> 3851     np.copyto(result, fill_value, where=m)
#    3852 except (TypeError, AttributeError):
#    3853     fill_value = narray(fill_value, dtype=object)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Read Hydrology Raster Data and Convert to Points, Sample flow at point, then make linkes

# %%
import sys
import numpy as np
import pandas as pd
sys.path.append('/opt/homebrew/lib/python3.10/site-packages')
sys.path.append('/opt/homebrew/lib/python3.11/site-packages')
sys.path.append('/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages')
import shapely
from shapely.geometry import Point, LineString
import geopandas as gpd
import basemap
import math
import requests
import json
import fiona
from openpyxl import load_workbook
import random
from statistics import mean


#import rasterio.plot
#import rasterio.mask
#import rasterio.features
import rasterstats

#import cfgrib

#%matplotlib inline

# add two empty columns to the river layer
river_hn_lines['flow']= np.empty((len(river_hn_lines), 0)).tolist()
# river_hn_lines['dist']= []
distance_of_sampling_points = 500

dataframe_list = []
line_dataframe_list = []

# take lines, interpolate points, sample raster, add flow to river layer
for i in river_hn_lines.index:
    river_segment = river_hn_lines.loc[i,'geometry']

    river_segment3857 = gpd.GeoSeries(river_segment, crs=4326).to_crs(epsg=3857)
    river_segment3857 = river_segment3857.iloc[0]

    distances = np.arange(0,river_segment3857.length,distance_of_sampling_points)

    river_segment_pnt = [river_segment3857.interpolate(distance) for distance in distances]
    river_segment_pnt = gpd.GeoSeries(river_segment_pnt, crs=3857).to_crs(river_raster.crs)
    result = rasterstats.point_query(river_segment_pnt, river_raster.read(1), nodata = river_raster.nodata, affine = river_raster.transform,interpolate='nearest')
    

    df_river_segment_pnt = gpd.GeoDataFrame(geometry=river_segment_pnt)
    df_river_segment_pnt['dist'] = distances
    df_river_segment_pnt['flow'] = result
    dataframe_list.append(df_river_segment_pnt)

    river_segment_line = river_segment_pnt.copy()

    # create line segments from points, add flow and distances. Thus lines can be plotted with flow as color or line width in QGIS
    if len(river_segment_line) > 1:
        for k in range(len(river_segment_line)-1):
            line = LineString([river_segment_line[k],river_segment_line[k+1]])
            river_segment_line[k] = line
        river_segment_line.drop(k+1, inplace = True)

        df_river_segment_line = gpd.GeoDataFrame(geometry=river_segment_line)
        df_river_segment_line['flow'] = result[:-1]
        df_river_segment_line['dist'] = distances[:-1]
        line_dataframe_list.append(df_river_segment_line)

rdf = gpd.GeoDataFrame(pd.concat(dataframe_list, ignore_index=True), crs=dataframe_list[0].crs)
ldf = gpd.GeoDataFrame(pd.concat(line_dataframe_list, ignore_index=True), crs=line_dataframe_list[0].crs)

ldf.to_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/hn_rivers_flow_lines.shp')
ldf.to_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/hn_rivers_flow_lines.gpkg')
rdf.to_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/hn_rivers_flow_points.shp')
rdf.to_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/hn_rivers_flow_points.gpkg')

# %% [markdown]
# ## Find Hexes with large Bodies of Water for Coins = INTERSECT CORINE CODE 90 512 OR 523 WITH THE HEXGRID

# %% [markdown]
# Hammers are harder. Cultivated vs Mined: sjoin Rivers, sjoin corine land cover. Arable land? Hex Type 7 6 or 5? Add one hammer if settlement
# Coins also Cultivated vs mined. Also Oasis

# %% [markdown]
# # Find Hexes with any rivers for well-watered areas = cultivated hexes. THIS DOES NOT EXCLUDE MOUNTAIN VALLEYS

# %%
# Read in hexgrid and add river flow to hexes
hexgrid10km = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10kmHungary Copy with Bread.shp')
river_flow_lines = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/hn_rivers_flow_lines.shp')
hexgrid10kmPOINTS = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10km Hex Features all.shp')
# Filter river flow for large rivers and set CRS
any_rivers = river_flow_lines.loc[river_flow_lines['flow'] > 1]
any_rivers = any_rivers.to_crs(hexgrid10km.crs)
# Add river flow to hexgrid https://geopandas.org/en/stable/gallery/spatial_joins.html
# then only retain the first match
hexes_with_any_rivers = gpd.sjoin(hexgrid10km, any_rivers, how ="inner", predicate='contains')
hexes_with_any_rivers.drop_duplicates(subset='IDX', keep='first', inplace=True) # this is what i want.

hexgrid10kmPOINTS['anyRiver'] = 0 * hexgrid10kmPOINTS.shape[0] #initialize new column
for i in hexgrid10kmPOINTS[hexgrid10kmPOINTS['IDX'].isin(hexes_with_any_rivers['IDX'])].index:
    #print(i)
    #print(hexgrid10kmPOINTS.loc[i,'anyRiver'])
    hexgrid10kmPOINTS.loc[i,'anyRiver'] = 1
    #print(hexgrid10kmPOINTS.loc[i,'anyRiver'])

hexgrid10kmPOINTS.to_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10km Hex Features all.shp')

# %% [markdown]
# ## Find Hexes with large Rivers for Hammers and Coins
# might be easier if done in QGIS but need data later on for calculation of Hammers and Coins

# %%
# Read in hexgrid and add river flow to hexes
hexgrid10km = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10kmHungary Copy with Bread.shp')
river_flow_lines = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/hn_rivers_flow_lines.shp')
hexgrid10kmPOINTS = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10km Hex Features all.shp')

# %%
# Filter river flow for large rivers and set CRS
large_rivers = river_flow_lines.loc[river_flow_lines['flow'] > 49]
large_rivers = large_rivers.to_crs(hexgrid10km.crs)

# %%
# Add river flow to hexgrid https://geopandas.org/en/stable/gallery/spatial_joins.html
# then only retain the first match
hexes_with_large_rivers = gpd.sjoin(hexgrid10km, large_rivers, how ="inner", predicate='contains')
hexes_with_large_rivers.drop_duplicates(subset='IDX', keep='first', inplace=True) # this is what i want.

# %%
hexgrid10kmPOINTS['largeRiver'] = 0 * hexgrid10kmPOINTS.shape[0] #initialize new column
for i in hexgrid10kmPOINTS[hexgrid10kmPOINTS['IDX'].isin(hexes_with_large_rivers['IDX'])].index:
    print(i)
    print(hexgrid10kmPOINTS.loc[i,'largeRiver'])
    hexgrid10kmPOINTS.loc[i,'largeRiver'] = 1
    print(hexgrid10kmPOINTS.loc[i,'largeRiver'])

# %%
hexgrid10kmPOINTS.to_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10km Hex Features all.shp')
# Out:
# /var/folders/0b/fbk22xnd4gs9_s54ynyblwtc0000gn/T/ipykernel_17508/3997959370.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   hexgrid10kmPOINTS.to_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10km Hex Features all.shp')

# %% [markdown]
# ## Find largest Ecoregion in 10km hexes

# %%
# Find largest Ecoregion in 10km hexes by area and write the name (an in the future maybe the ID) to the 10km hexes
hexgrid10kmPOLYGONS = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10kmHungarybreadRevised.shp')

hexgrid10kmPOINTS = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10km Hex Features all.shp')

ecoregions_subset = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/Ecoregions subset.shp')
ecoregions_subset = ecoregions_subset.to_crs('EPSG:3857')
largest_ecoregion_in_10kmhexes = {}
for hex in hexgrid10kmPOLYGONS[pd.notna(hexgrid10kmPOLYGONS.geometry)].iterrows():
    ecoregions_in_hexNAME = {}
    ecoregions_in_hexID = {}
    for ecoregion in ecoregions_subset.iterrows():
        intersects = shapely.intersection(ecoregion[1].geometry, hex[1].geometry)
        if intersects.area != 0:
            ecoregions_in_hexNAME[ecoregion[1]['ECO_NAME']] = intersects.area
            ecoregions_in_hexID[ecoregion[1]['ECO_ID']] = intersects.area
    #print(ecoregions_in_hex)
    if ecoregions_in_hexNAME != {}: # can be empty if there is no ecoregion (in the sea)
        largest_ecoregion_in_this_hexNAME = max(ecoregions_in_hexNAME, key = ecoregions_in_hexNAME.get) #https://docs.python.org/3/library/functions.html#max, max accepts a keyword argument to preprocess the values
        largest_ecoregion_in_this_hexID = max(ecoregions_in_hexID, key = ecoregions_in_hexID.get)
        largest_ecoregion_in_10kmhexes[hex[1]['IDX']]= [largest_ecoregion_in_this_hexNAME,largest_ecoregion_in_this_hexID]
#print(largest_ecoregion_in_10kmhexes)


hexgrid10kmPOINTS['ECO_NAME'] = '' * hexgrid10km.shape[0]
hexgrid10kmPOINTS['ECO_ID'] = 0 * hexgrid10km.shape[0]
for key, value in largest_ecoregion_in_10kmhexes.items():
    hexgrid10kmPOINTS.loc[hexgrid10kmPOINTS['IDX'] == key, 'ECO_NAME'] = value[0]
    hexgrid10kmPOINTS.loc[hexgrid10kmPOINTS['IDX'] == key, 'ECO_ID'] = value[1]

hexgrid10kmPOINTS.to_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10km Hex Features all.shp')

# %% [markdown]
# # Mark Hexes with large Lakes for Coin Calculation. ## Find Hexes with large Bodies of Water for Coins = INTERSECT CORINE CODE 90 512 OR 523 WITH THE HEXGRID

# %%
corine= gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/u2000_clc1990_v2020_20u1_geoPackage/DATA/U2000_CLC1990_V2020_20u1.gpkg', layer='u2000_clc1990_v2020_20u1')

# %%
hexgrid10kmPOLYGONS = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10kmHungarybreadRevised.shp')

hexgrid10kmPOINTS = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10km Hex Features all.shp')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 hexgrid10kmPOLYGONS = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10kmHungarybreadRevised.shp')
#       3 hexgrid10kmPOINTS = gpd.read_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10km Hex Features all.shp')
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/geopandas/io/file.py:297, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     294     else:
#     295         path_or_bytes = filename
# --> 297     return _read_file_fiona(
#     298         path_or_bytes, from_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     299     )
#     301 else:
#     302     raise ValueError(f"unknown engine '{engine}'")
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/geopandas/io/file.py:395, in _read_file_fiona(path_or_bytes, from_bytes, bbox, mask, rows, where, **kwargs)
#     391     df = pd.DataFrame(
#     392         [record["properties"] for record in f_filt], columns=columns
#     393     )
#     394 else:
# --> 395     df = GeoDataFrame.from_features(
#     396         f_filt, crs=crs, columns=columns + ["geometry"]
#     397     )
#     398 for k in datetime_fields:
#     399     as_dt = pd.to_datetime(df[k], errors="ignore")
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/geopandas/geodataframe.py:641, in GeoDataFrame.from_features(cls, features, crs, columns)
#     638 if hasattr(feature, "__geo_interface__"):
#     639     feature = feature.__geo_interface__
#     640 row = {
# --> 641     "geometry": shape(feature["geometry"]) if feature["geometry"] else None
#     642 }
#     643 # load properties
#     644 properties = feature["properties"]
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/shapely/geometry/geo.py:102, in shape(context)
#     100     return LinearRing(ob["coordinates"])
#     101 elif geom_type == "polygon":
# --> 102     return Polygon(ob["coordinates"][0], ob["coordinates"][1:])
#     103 elif geom_type == "multipoint":
#     104     return MultiPoint(ob["coordinates"])
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/shapely/geometry/polygon.py:230, in Polygon.__new__(self, shell, holes)
#     228     return shell
#     229 else:
# --> 230     shell = LinearRing(shell)
#     232 if holes is not None:
#     233     if len(holes) == 0:
#     234         # shapely constructor cannot handle holes=[]
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/shapely/geometry/polygon.py:104, in LinearRing.__new__(self, coordinates)
#      99 if len(coordinates) == 0:
#     100     # empty geometry
#     101     # TODO better constructor + should shapely.linearrings handle this?
#     102     return shapely.from_wkt("LINEARRING EMPTY")
# --> 104 geom = shapely.linearrings(coordinates)
#     105 if not isinstance(geom, LinearRing):
#     106     raise ValueError("Invalid values passed to LinearRing constructor")
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/shapely/decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/shapely/creation.py:173, in linearrings(coords, y, z, indices, out, **kwargs)
#     171 coords = _xyz_to_coords(coords, y, z)
#     172 if indices is None:
# --> 173     return lib.linearrings(coords, out=out, **kwargs)
#     174 else:
#     175     return simple_geometries_1d(coords, indices, GeometryType.LINEARRING, out=out)
#
# KeyboardInterrupt:

# %%
corine.to_crs('EPSG:3857', inplace = True)

# %%
large_lakes = corine.loc[corine['Area_Ha'] > 1000]

# %%
large_lakes = large_lakes.loc[((large_lakes['code_90'] == '523') | (large_lakes['code_90'] == '512'))]

# %%
hexes_with_large_lakes = gpd.sjoin(hexgrid10kmPOLYGONS, large_lakes, how ="inner", predicate='intersects')
hexes_with_large_lakes.drop_duplicates(subset='IDX', keep='first', inplace=True) # this is what i want.

# %%
hexgrid10kmPOINTS['largeLake'] = 0 * hexgrid10kmPOINTS.shape[0] #initialize new column
for i in hexgrid10kmPOINTS[hexgrid10kmPOINTS['IDX'].isin(hexes_with_large_lakes['IDX'])].index:
    # print(i)
    # print(hexgrid10kmPOINTS.loc[i,'largeLake'])
    hexgrid10kmPOINTS.loc[i,'largeLake'] = 1
    # print(hexgrid10kmPOINTS.loc[i,'largeLake'])

# %%
hexgrid10kmPOINTS.to_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10km Hex Features all.shp')

# %% [markdown]
# # set_hammers findig cultivated is fuzzy

# %%
# set_hammers
# Any type of hex from 1 to 7, that appears in a well-watered valleys, hills or plains, is considered cultivated. SO I CHECK FOR THE PRESENCE OF A RIVER OR A LAKE
# In addition to the coins added by type, an additional +1 coin is awarded if the hex is located on a body of water that's at least four square miles in area, AND if the hex is a type 1 to 6 hex. The amount of land on the hex must also equal at least 4 square miles. Thus, lakeshores and coastal hexes collect more coins, thus having more active economies than inland hexes. Water-borne trade brings many more customers and is much more interesting as a place to invest. 
# A +1 coin is also given for each settlement a hex includes. SO CHECK FOR THE PRESENCE OF A SETTLEMENT.
# maybe go for a minimum area without stark slopes?

def set_hammers(hexgrid10kmPOINTS):
    hammers = {'cultivated' : {'0': -1,'1': 4, '2':4, '3':3 , '4':2, '5':1, '6':1, '7': 0, '8':0 },
            'mined' : {'0': -1,'1': -2, '2':-2, '3': -2, '4':-2, '5':3, '6':2, '7': 2, '8': 0}
            }

    hexgrid10kmPOINTS['hammers'] = 0 * hexgrid10kmPOINTS.shape[0] #initialize new column
    hexgrid10kmPOINTS['cultivated'] = 0 * hexgrid10kmPOINTS.shape[0] #initialize new column
    hexgrid10kmPOINTS['mined'] = 0 * hexgrid10kmPOINTS.shape[0] #initialize new column
    for i in hexgrid10kmPOINTS.index:
        # if any([pd.notna(hexgrid10km.loc[i,'main_commo']), pd.notna(hexgrid10km.loc[i,'commodity']),pd.notna(hexgrid10km.loc[i,'IDminingfe'])]):
        # hexgrid10km.loc[i,'Bread'] = -1
        # Hextype of corner hexes is 0!
        if hexgrid10kmPOINTS.loc[i, 'anyRiver'] == 1: # surrogate parameter for well-watered valleys, hills or plains, assuming that riverrs in mountains are smaller
            hexgrid10kmPOINTS.loc[i,'cultivated'] = 1
            hexgrid10kmPOINTS.loc[i,'hammers'] = hammers['cultivated'][hexgrid10kmPOINTS.loc[i,'HexType'].astype(int).astype(str)]
        if pd.notna(hexgrid10kmPOINTS.loc[i, 'label']):
            hexgrid10kmPOINTS.loc[i,'mined'] = 1
            hexgrid10kmPOINTS.loc[i,'hammers'] = hammers['mined'][hexgrid10kmPOINTS.loc[i,'HexType'].astype(int).astype(str)]
        if pd.notna(hexgrid10kmPOINTS.loc[i,'IDsettl']):
            hexgrid10kmPOINTS.loc[i,'hammers'] += 1
        if hexgrid10kmPOINTS.loc[i, 'largeRiver'] == 1:
            hexgrid10kmPOINTS.loc[i,'hammers'] += 1 # In addition to the hammers added by type, an additional +1 hammer is awarded if the hex includes a sufficiently sized river.
    return hexgrid10kmPOINTS

hexgrid10kmPOINTS = set_hammers(hexgrid10kmPOINTS)
hexgrid10kmPOINTS.to_file('/Users/aljoschabeyer/Library/Mobile Documents/iCloud~md~obsidian/Documents/RPG/000 media/Maps/QGIS/10km Hex Features all.shp')

# %% [markdown]
# # set_coins

# %%
# Read in, now truncated colum lables
# Any type of hex from 1 to 7, that appears in a well-watered valleys, hills or plains, is considered cultivated. SO I CHECK FOR THE PRESENCE OF A RIVER OR A LAKE
# In addition to the coins added by type, an additional +1 coin is awarded if the hex is located on a body of water that's at least four square miles in area, AND if the hex is a type 1 to 6 hex. The amount of land on the hex must also equal at least 4 square miles. Thus, lakeshores and coastal hexes collect more coins, thus having more active economies than inland hexes. Water-borne trade brings many more customers and is much more interesting as a place to invest. 
# A +1 coin is also given for each settlement a hex includes. SO CHECK FOR THE PRESENCE OF A SETTLEMENT.

def set_coins(hexgrid10kmPOINTS):
    coins = {'cultivated' : {'0': -1,'1': 5, '2':3, '3':2 , '4':1, '5':0, '6':0, '7': 0, '8':0 },
            'mined' : {'0': -1,'1': -2, '2':-2, '3': -2, '4':-2, '5':1, '6':1, '7': 0, '8': 0},
            'oasis' : {'0': -1,'1': 6, '2':4, '3': 3, '4':2, '5':0, '6':0, '7': 0, '8': 0}
             }

    hexgrid10kmPOINTS['coins'] = 0 * hexgrid10kmPOINTS.shape[0] #initialize new column
    for i in hexgrid10kmPOINTS.index:
        hexgrid10kmPOINTS.loc[i,'coins'] = 0
        # if any([pd.notna(hexgrid10km.loc[i,'main_commo']), pd.notna(hexgrid10km.loc[i,'commodity']),pd.notna(hexgrid10km.loc[i,'IDminingfe'])]):
        # hexgrid10km.loc[i,'Bread'] = -1
        # Hextype of corner hexes is 0!

        if hexgrid10kmPOINTS.loc[i,'cultivated'] == 1:
            hexgrid10kmPOINTS.loc[i,'coins'] = coins['cultivated'][hexgrid10kmPOINTS.loc[i,'HexType'].astype(int).astype(str)]
        if hexgrid10kmPOINTS.loc[i,'mined'] == 1:
            hexgrid10kmPOINTS.loc[i,'coins'] = coins['mined'][hexgrid10kmPOINTS.loc[i,'HexType'].astype(int).astype(str)]

        if pd.notna(hexgrid10kmPOINTS.loc[i,'IDsettl']):
            hexgrid10kmPOINTS.loc[i,'coins'] += 1

        if ((hexgrid10kmPOINTS.loc[i, 'largeLake'] == 1) and (hexgrid10kmPOINTS.loc[i, 'HexType'] < 7)):
            hexgrid10kmPOINTS.loc[i,'coins'] += 1 # In addition to the hammers added by type, an additional +1 hammer is awarded if the hex includes a sufficiently sized river.

    return hexgrid10kmPOINTS

hexgrid10kmPOINTS = set_coins(hexgrid10kmPOINTS)
